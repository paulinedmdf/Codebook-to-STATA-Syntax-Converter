# %% [markdown]
# ### Importing OS and CSV modules

# %%
# list files in a directory using :os.path.join
import os

# import csv files
import csv

# %% [markdown]
# ### Importing CSV file
# In order to import your codebook, first ensure that it is saved as a csv file.
#
# Under 'data_dir', replace the path name with the path your csv file is located in.
#
# Under 'csv_file', replace "codebook_file.csv" with the name of your csv file.

# %%
# file directory
data_dir = "/Users/pauli/OneDrive - Johns Hopkins/Center for Communications Programs/Codebook-to-STATA-Syntax-Converter-master" 

# file name
csv_file = os.path.join(data_dir, "codebook_file.csv")
type(csv_file)
# Out:
# str

# %% [markdown]
# Checking that we are able to successfully read the first colum of our CSV file

# %%
with open(csv_file, 'r') as f:
    reader = csv.reader(f, delimiter = ',') # saving contents to variable 'reader'
    for line in reader:
        print (line[0]) # reading the first colum
# Out:
# variable
# casenum
# SubmissionDate
# valid_age
# confirmation
# name
# Signature
# Date
# confirmation_2
# region
# province
# city_municipality
# barangay
# residence
# household_number
# hhmem_code
# A01
# A02
# A03
# A03_others
# A04
# A05
# A05_others
# A06
# A07
# A08
# A09
# A10
# A11
# A11_others
# A12
# A13
# A13_A
# A13_B
# A13_C
# A13_D
# A13_E
# A13_F
# A13_G
# A13_H
# A13_I
# A13_J
# A13_K
# A13_L
# A13_M
# A13_N
# A13_O
# A14
# A15
# A16
# A17_A_Distance
# A17_B_Distance
# A17_C_Distance
# A17_D_Distance
# A17_E_Distance
# A17_A_TimeWalking
# A17_B_TimeWalking
# A17_C_TimeWalking
# A17_D_TimeWalking
# A17_E_TimeWalking
# A17_A_ByCar
# A17_B_ByCar
# A17_C_ByCar
# A17_D_ByCar
# A17_E_ByCar
# B1
# B2
# B3
# B4
# B5
# B6
# B7
# B7_others
# B8
# B9
# B9_A
# B9_B
# B9_C
# B9_D
# B9_E
# B9_F
# B9_G
# B9_H
# B9_I
# B9_J
# B9_K
# B9_L
# B9_M
# B9_N
# B9_O
# B9_P
# B9_Q
# B9_R
# B9_S
# B9_T
# B9_U
# B9_V
# B9_W
# B9_Y
# B9_X
# B9_Z
# B9_AA
# B9_AB
# B9_AC
# B9_AD
# B9_AE
# B9_AF
# B9_AG
# B9_AH
# B9_AI
# B9_other
# B10
# B11
# B12
# B13
# B13_A
# B13_B
# B13_C
# B13_D
# B13_E
# B13_98
# B13_other
# B14
# B15
# B15_A
# B15_B
# B15_C
# B15_D
# B15_E
# B15_F
# B15_G
# B15_H
# B15_I
# B15_J
# B15_K
# B15_L
# B15_M
# B15_N
# B15_O
# B15_P
# B15_Q
# B15_R
# B15_98
# B15_99
# B15_other
# B16
# B16_A
# B16_B
# B16_C
# B16_D
# B16_E
# B16_F
# B16_G
# B16_H
# B16_I
# B16_J
# B16_K
# B16_L
# B16_M
# B16_N
# B16_O
# B16_P
# B16_98
# B16_other
# B17
# B18
# B19
# B20
# B20_A
# B20_B
# B20_C
# B20_D
# B20_0
# B21
# B22
# B22_other
# B23
# B24
# B24_A
# B24_B
# B24_C
# B24_D
# B24_E
# B24_F
# B24_G
# B24_H
# B24_I
# B24_J
# B24_K
# B24_L
# B24_98
# B24_99
# B24_other
# B25
# B25_A
# B25_B
# B25_C
# B25_D
# B25_E
# B25_F
# B25_G
# B25_H
# B25_I
# B25_J
# B25_K
# B25_98
# B25_other
# B26
# B27_repeat_count
# count_hm_1
# HM_1
# count_hm_2
# HM_2
# count_hm_3
# HM_3
# count_hm_4
# HM_4
# count_hm_5
# HM_5
# B28
# B29
# B30
# B31
# B32
# B32_A
# B32_B
# B32_C
# B32_D
# B32_E
# B32_F
# B32_G
# B32_H
# B32_I
# B32_J
# B32_K
# B32_98
# B32_other
# B33
# B34
# B34_A
# B34_B
# B34_C
# B34_D
# B34_E
# B34_F
# B34_G
# B34_H
# B34_I
# B34_J
# B34_K
# B34_L
# B34_M
# B34_98
# B34_other
# B35
# B35_A
# B35_B
# B35_C
# B35_D
# B35_E
# B35_F
# B35_G
# B35_H
# B35_I
# B35_J
# B35_K
# B35_L
# B35_98
# B35_99
# B35_other
# C01_spontaneous
# C01_spontaneous_A
# C01_spontaneous_B
# C01_spontaneous_C
# C01_spontaneous_D
# C01_spontaneous_E
# C01_spontaneous_F
# C01_spontaneous_G
# C01_spontaneous_H
# C01_spontaneous_I
# C01_spontaneous_99
# C01_spontaneous_98A
# C01_Spontaneous_Other
# C01_probe
# C01_probe_F
# C01_probe_G
# C01_probe_H
# C01_probe_I
# C01_probe_J
# C01_probe_K
# C01_probe_L
# C01_probe_M
# C01_probe_N
# C01_probe_99
# C01_probe_98B
# C01_Probe_Other
# C02
# C02_A
# C02_B
# C02_C
# C02_D
# C02_E
# C02_F
# C02_G
# C02_H
# C02_I
# C02_J
# C02_K
# C02_L
# C02_M
# C02_N
# C02_O
# C02_P
# C02_99
# C02_98
# C02_Other
# C03
# C03_Other
# C04
# C04_A
# C04_B
# C04_C
# C04_D
# C04_E
# C04_F
# C04_G
# C04_H
# C04_I
# C04_J
# C04_98
# C04_99
# C04_Other
# C04_Other1
# C05
# C06
# C07
# C08
# C09
# C10
# C11
# C12
# C13
# C14
# C15
# C16
# C17
# C18
# C19
# C20
# C21
# C22
# D01
# D01_A
# D01_B
# D01_C
# D01_D
# D01_E
# D01_F
# D01_G
# D01_H
# D01_I
# D01_J
# D01_K
# D01_L
# D01_M
# D01_N
# D01_O
# D01_P
# D01_Q
# D01_R
# D01_S
# D01_T
# D01_U
# D01_V
# D01_W
# D01_X
# D01_Y
# D01_Z
# D01_A2
# D01_A1
# D01_98
# D01_Other
# D02
# D03
# D04
# D05
# D05_A
# D05_B
# D05_C
# D05_D
# D05_E
# D05_F
# D05_G
# D05_H
# D05_I
# D05_J
# D05_K
# D05_L
# D05_M
# D05_N
# D05_O
# D05_P
# D05_Q
# D05_R
# D05_S
# D05_T
# D05_U
# D05_V
# D05_W
# D05_X
# D05_Y
# D05_Z
# D05_AA
# D05_AB
# D05_AC
# D05_AD
# D05_AE
# D05_AF
# D05_AG
# D05_98
# D05_Others
# D06
# D07
# D07_A
# D07_B
# D07_C
# D07_D
# D07_E
# D07_F
# D07_G
# D07_H
# D07_I
# D07_98
# D07_Others
# D08
# D09
# D10_A
# D10_B
# D10_C
# D10_D
# D10_E
# D10_F
# D10_G
# D10_H
# D10_I
# D10_J
# D10_K
# D10_L
# D11
# D11_A
# D11_B
# D11_C
# D11_D
# D11_E
# D11_F
# D11_G
# D12
# D12_Others
# D13_A
# D13_B
# D13_C
# D13_D
# D13_E
# D13_F
# D13_G
# D13_H
# D13_I
# D13_J
# D14
# D15
# D16
# D17
# D17_A
# D17_B
# D17_C
# D17_D
# D17_E
# D17_F
# D17_G
# D17_H
# D17_I
# D17_J
# D17_K
# D17_L
# D17_M
# D17_98
# D17_Other
# D18
# D18_A
# D18_B
# D18_C
# D18_D
# D18_E
# D18_F
# D18_G
# D18_H
# D18_I
# D18_J
# D18_K
# D18_L
# D18_M
# D18_N
# D18_O
# D18_P
# D18_Q
# D18_R
# D18_S
# D18_T
# D18_U
# D18_V
# D18_W
# D18_X
# D18_Y
# D18_Z
# D18_A2
# D18_A1
# D18_98
# D18_Other
# D19
# D20
# D21
# D21_A
# D21_B
# D21_C
# D21_D
# D21_E
# D21_F
# D21_G
# D21_H
# D21_I
# D21_J
# D21_K
# D21_L
# D21_M
# D21_N
# D21_O
# D21_P
# D21_Q
# D21_R
# D21_S
# D21_T
# D21_98
# D21_99
# D21_other
# D22
# D22_A
# D22_B
# D22_C
# D22_D
# D22_E
# D22_F
# D22_G
# D22_H
# D22_I
# D22_J
# D22_K
# D22_L
# D22_M
# D22_N
# D22_O
# D22_P
# D22_Q
# D22_R
# D22_S
# D22_T
# D22_U
# D22_V
# D22_W
# D22_X
# D22_Y
# D22_98
# D22_99
# D22_Z
# D22_AA
# D22_other
# D23
# D23_A
# D23_B
# D23_C
# D23_D
# D23_E
# D23_F
# D23_G
# D23_H
# D23_I
# D23_J
# D23_K
# D23_L
# D23_M
# D23_N
# D23_98
# D23_99
# D23_other
# D24
# D25
# D25_A
# D25_B
# D25_C
# D25_D
# D25_E
# D25_F
# D25_G
# D25_H
# D25_99
# D26
# D26_A
# D26_B
# D26_C
# D26_D
# D26_E
# D26_F
# D26_G
# D26_H
# D26_I
# D26_J
# D26_K
# D26_L
# D26_M
# D26_N
# D26_O
# D26_P
# D26_Q
# D26_R
# D26_S
# D26_T
# D26_U
# D26_98
# D26_99
# D26_OTHER
# D27
# D28
# D28_A
# D28_B
# D28_C
# D28_D
# D28_E
# D28_98
# D28_OTHER
# D29
# D30
# D31
# D31_A
# D31_B
# D31_C
# D31_D
# D31_E
# D31_F
# D31_G
# D31_H
# D31_98
# D31_99
# D31_OTHER
# D32
# D32_A
# D32_B
# D32_C
# D32_D
# D32_E
# D32_F
# D32_G
# D32_H
# D32_I
# D32_J
# D32_K
# D32_L
# D32_M
# D32_N
# D32_O
# D32_P
# D32_Q
# D32_R
# D32_S
# D32_T
# D32_U
# D32_V
# D32_W
# D32_98
# D32_99
# D32_OTHER
# D33
# D34
# D34_A
# D34_B
# D34_C
# D34_D
# D34_E
# D34_98
# D34_OTHER
# D35
# D36
# D37
# D37_A
# D37_B
# D37_C
# D37_D
# D37_98
# D37_99
# D37_OTHER
# D38
# D38_A
# D38_B
# D38_C
# D38_D
# D38_E
# D38_F
# D38_G
# D38_H
# D38_I
# D38_J
# D38_K
# D38_L
# D38_M
# D38_N
# D38_O
# D38_P
# D38_Q
# D38_R
# D38_S
# D38_98
# D38_99
# D38_OTHER
# D39
# D40
# D40_A
# D40_B
# D40_C
# D40_D
# D40_E
# D40_98
# D40_OTHER
# D41
# D42
# D43
# D43_A
# D43_B
# D43_C
# D43_D
# D43_98
# D43_99
# D43_OTHER
# D44
# D44_A
# D44_B
# D44_C
# D44_D
# D44_E
# D44_F
# D44_G
# D44_H
# D44_I
# D44_J
# D44_K
# D44_L
# D44_M
# D44_N
# D44_O
# D44_P
# D44_Q
# D44_R
# D44_S
# D44_98
# D44_99
# D44_OTHER
# D45
# D46
# D46_A
# D46_B
# D46_C
# D46_D
# D46_E
# D46_98
# D46_OTHER
# D47
# D48
# D49
# D49_A
# D49_B
# D49_C
# D49_D
# D49_98
# D49_99
# D49_OTHER
# D50
# D50_A
# D50_B
# D50_C
# D50_D
# D50_E
# D50_F
# D50_G
# D50_H
# D50_I
# D50_J
# D50_K
# D50_L
# D50_M
# D50_N
# D50_O
# D50_P
# D50_Q
# D50_R
# D50_S
# D50_T
# D50_U
# D50_98
# D50_99
# D50_OTHER
# D51
# D52
# D52_A
# D52_B
# D52_C
# D52_D
# D52_E
# D52_98
# D52_OTHER
# D53
# D54
# D55
# D55_A
# D55_B
# D55_C
# D55_D
# D55_E
# D55_98
# D55_99
# D55_OTHER
# D56
# D56_A
# D56_B
# D56_C
# D56_D
# D56_E
# D56_F
# D56_G
# D56_H
# D56_I
# D56_J
# D56_K
# D56_L
# D56_M
# D56_N
# D56_O
# D56_P
# D56_Q
# D56_R
# D56_S
# D56_98
# D56_99
# D56_OTHER
# D57
# D58
# D58_A
# D58_B
# D58_C
# D58_D
# D58_E
# D58_98
# D58_OTHER
# D59
# D60
# D61
# D61_A
# D61_B
# D61_C
# D61_D
# D61_98
# D61_99
# D61_OTHER
# D62
# D62_A
# D62_B
# D62_C
# D62_D
# D62_E
# D62_F
# D62_G
# D62_H
# D62_I
# D62_J
# D62_K
# D62_L
# D62_M
# D62_N
# D62_O
# D62_P
# D62_Q
# D62_R
# D62_S
# D62_98
# D62_99
# D62_OTHER
# D63
# D64
# D64_A
# D64_B
# D64_C
# D64_D
# D64_E
# D64_98
# D64_OTHER
# D65
# D66
# D67
# D67_A
# D67_B
# D67_C
# D67_D
# D67_E
# D67_F
# D67_98
# D67_99
# D67_OTHER
# D68
# D68_A
# D68_B
# D68_C
# D68_D
# D68_E
# D68_F
# D68_G
# D68_H
# D68_I
# D68_J
# D68_K
# D68_L
# D68_M
# D68_N
# D68_O
# D68_P
# D68_Q
# D68_R
# D68_S
# D68_T
# D68_98
# D68_99
# D68_OTHER
# D69
# D70
# D70_A
# D70_B
# D70_C
# D70_D
# D70_E
# D70_98
# D70_OTHER
# D71
# D72
# D73
# D73_A
# D73_B
# D73_C
# D73_D
# D73_E
# D73_F
# D73_98
# D73_99
# D73_OTHER
# D74
# D74_A
# D74_B
# D74_C
# D74_D
# D74_E
# D74_F
# D74_G
# D74_H
# D74_I
# D74_J
# D74_K
# D74_L
# D74_M
# D74_N
# D74_O
# D74_P
# D74_Q
# D74_R
# D74_S
# D74_T
# D74_98
# D74_99
# D74_OTHER
# D75
# D76
# D76_A
# D76_B
# D76_C
# D76_D
# D76_E
# D76_98
# D76_OTHER
# D77
# D78
# D79
# D79_A
# D79_B
# D79_C
# D79_D
# D79_98
# D79_99
# D79_OTHER
# D80
# D80_A
# D80_B
# D80_C
# D80_D
# D80_E
# D80_F
# D80_G
# D80_H
# D80_I
# D80_J
# D80_K
# D80_L
# D80_M
# D80_N
# D80_O
# D80_P
# D80_Q
# D80_R
# D80_S
# D80_T
# D80_98
# D80_99
# D80_OTHER
# D81
# D82
# D82_A
# D82_B
# D82_C
# D82_D
# D82_E
# D82_98
# D82_OTHER
# D83
# simserial
# today
# starttime
# endtime
# deviceid
# subscriberid
# simid
# devicephonenum
# username
# device_info
# duration
# instanceID
# formdef_version
# KEY
# KEY_HH
# A1_1
# A2_1
# A3_1
# A4_1
# A5_1
# A6_1
# count_household_2
# A1_2
# A2_2
# A3_2
# A4_2
# A5_2
# A6_2
# count_household_3
# A1_3
# A2_3
# A3_3
# A4_3
# A5_3
# A6_3
# count_household_4
# A1_4
# A2_4
# A3_4
# A4_4
# A5_4
# A6_4
# count_household_5
# A1_5
# A2_5
# A3_5
# A4_5
# A5_5
# A6_5
# count_household_6
# A1_6
# A2_6
# A3_6
# A4_6
# A5_6
# A6_6
# count_household_7
# A1_7
# A2_7
# A3_7
# A4_7
# A5_7
# A6_7
# count_household_8
# A1_8
# A2_8
# A3_8
# A4_8
# A5_8
# A6_8
# count_household_9
# A1_9
# A2_9
# A3_9
# A4_9
# A5_9
# A6_9
# count_household_10
# A1_10
# A2_10
# A3_10
# A4_10
# A5_10
# A6_10
# count_household_11
# A1_11
# A2_11
# A3_11
# A4_11
# A5_11
# A6_11
# count_household_12
# A1_12
# A2_12
# A3_12
# A4_12
# A5_12
# A6_12
# count_household_13
# A1_13
# A2_13
# A3_13
# A4_13
# A5_13
# A6_13
# count_household_14
# A1_14
# A2_14
# A3_14
# A4_14
# A5_14
# A6_14
# count_household_15
# A1_15
# A2_15
# A3_15
# A4_15
# A5_15
# A6_15
# count_household_16
# A1_16
# A2_16
# A3_16
# A4_16
# A5_16
# A6_16
# count_household_17
# A1_17
# A2_17
# A3_17
# A4_17
# A5_17
# A6_17
# count_household_18
# A1_18
# A2_18
# A3_18
# A4_18
# A5_18
# A6_18
# num_household
# today_hh
# starttime_hh
# endtime_hh
# deviceid_hh
# subscriberid_hh
# simid_hh
# devicephonenum_hh
# username_hh
# device_info_hh
# duration_hh
# instanceID_hh
# formdef_version_hh

# %% [markdown]
# Getting a list of all of the response options

# %%
with open(csv_file, 'r') as f:
    reader = csv.reader(f, delimiter = ',')
    header = next(reader)
    for line in reader:
        responseopt = line[2]
        print (responseopt)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# 1 “National Capital Region” 2 “Cordillera Autonomous Region” 3 “Central Luzon” 4 “MIMAROPA” 5 “Central Visayas” 6 “Western Visayas” 7 “Northern Mindanao” 8 “Bangsamoro Autonomous Region in Muslim Mindanao”
# 1 “Caloocan” 2 “Navotas” 3 “Valenzuela” 4 “Las Piñas” 5 “Makati” 6 “Muntinlupa” 7 “Parañaque” 8 “Pasay” 9 “Taguig” 10 “Manila” 11 “Mandaluyong” 12 “Marikina” 13 “Pasig” 14 “Quezon City” 15 “San Juan City” 16 “Ifugao” 17 “Pampanga” 18 “Palawan” 19 “Negros Oriental” 20 “Iloilo” 21 “Misamis Oriental” 22 “Basilan” 23 “Sulu” 24 “Maguindanao”
# 1 “Caloocan” 2 “Navotas” 3 “Valenzuela” 4 “Las Piñas” 5 “Makati” 6 “Muntinlupa” 7 “Parañaque” 8 “Pasay” 9 “Taguig” 10 “Tondo” 11 “Santa Cruz” 12 “Intramuros” 13 “Santa Ana” 14 “Mandaluyong” 15 “Marikina” 16 “Pasig” 17 “Quezon City” 18 “San Juan” 19 “Alfonso Lista” 20 “Santa Ana” 21 “Lubao” 22 “Floridablanca” 23 “Magalang” 24 “City of San Fernando (capital)” 25 “City of Angeles” 26 “Linapacacn” 27 “Rizal” 28 “Narra” 29 “Mabinay” 30 “City of Tanjay” 31 “City of Bayawan” 32 “Jimalalud” 33 “City of Iloilo (Capital)” 34 “City of Passi” 35 “Tigbauan” 36 “Calinog” 37 “Salay” 38 “City of Cagayan de Oro (capital)” 39 “Lantawan” 40 “Old Panamao” 41 “Talipao” 42 “Siasi” 43 “Datu Unsay” 44 “Kabuntalan Tumbao” 45 “Sultan Kudarat”
# 1 “Barangay 88” 2 “Barangay 171” 3 “Barangay 176” 4 “Barangay 188” 5 “Sipac-Almacen” 6 “Gen. T. De Leon” 7 “Ugong” 8 “Pamplona Tres” 9 “Palanan” 10 “Alabang” 11 “Sucat” 12 “Marcelo Green Village” 13 “Barangay 57” 14 “Tanyag” 15 “Ususan” 16 “South Signal Village” 17 “Barangay 142” 18 “Barangay 377” 19 “Barangay 658” 20 “Barangay 786” 21 “Namayan” 22 “Marikina Heights” 23 “Pinagbuhatan” 24 “Ugong” 25 “Bahay Toro” 26 “Donya Imelda” 27 “Matandang Balara” 28 “Ramon Magsaysay” 29 “South Triangle” 30 “Payatas” 31 “Ermitano” 32 “Pinto” 33 “Santo Rosario” 34 “Santo Cristo” 35 “San Nicolas” 36 “San Pedro II” 37 “San Nicolas” 38 “Pulung Maragul” 39 “Calibangbangan” 40 “Ransang” 41 “Panacan 2” 42 “Cansal-ing” 43 “San Miguel” 44 “Villasol” 45 “North Poblacion” 46 “San Antonio” 47 “Aglalana” 48 “Tan Pael” 49 “Simsiman” 50 “Gustilo” 51 “Inobulan” 52 “Puerto” 53 “Balulang” 54 “Canibungan” 55 “Tubig Gantang” 56 “Kabatuhan Bilaan” 57 “Siowing” 58 “Tuntungan” 59 “Buterin” 60 “Limbo”
# 1 “Urban” 2 “Rural”
# None
# None
# None
# 1 “Female” 2 “Male”
# 11 “Housewife” 12 “Civil Servant” 13 “Professional” 14 “Private Employee” 15 “Farmer / Owner of Farm” 16 “Fisherman/ Owner of Boat” 17 “Renting out boat / car/ motorcycle/ house” 18 “Entrepreneur / owner of a salon/car service/ sari-sari store” 19 “Trader” 20 “Day Labour / Agriculutural / Fishing / Driver” 21 “Honorarium Based worker” 22 “Student” 23 “Not working” 24 “Add: OFW” 98 “Other (Specify)”
# None
# 0 “No entry/response” 1 “Less than PHP 10,957 per month” 2 “PHP 10,957 – PHP 21,914” 3 “PHP 21,915 – PHP 43,828” 4 “PHP 43,829 – PHP 76,699” 5 “PHP 77,000 – PHP 131,483” 6 “PHP 131,484 – PHP 219,140” 7 “At least PHP 219,140”
# 0 “No Religion” 1 “Roman Catholic” 2 “Protestant” 3 “Iglesia Ni Cristo” 4 “Aglipay” 5 “Islam” 6 “Add: Born Again Christian” 7 “Add: Seventh Day Adventist” 8 “Add: The Church of Jesus Christ of Latter-day Saints” 98 “Other (Specify)”
# None
# 0 “None” 1 “Some Primary” 2 “Completed Primary” 3 “Some Secondary” 4 “Completed Secondary” 5 “Higher Ed/ College/ University”
# 0 “Never Married” 1 “Married” 2 “Living with someone as if Married” 3 “Separated” 4 “Widowed”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 1 “Own house and lot or owner-like possession of house and lot” 2 “Own house, rent lot” 3 “Own house rent free lot with consent of owner” 4 “Own house rent free lot without consent of owner” 5 “Rent house/room including lot” 6 “Rent free house and lot with consent of owner” 7 “Rent free house and lot without consent of owner” 98 “Other (Specify)”
# None
# None
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# 11 “Five kilometers or less” 12 “5-10 kms” 13 “Ten or more kilometers” 19 “Don't know”
# 11 “Five kilometers or less” 12 “5-10 kms” 13 “Ten or more kilometers” 19 “Don't know”
# 11 “Five kilometers or less” 12 “5-10 kms” 13 “Ten or more kilometers” 19 “Don't know”
# 11 “Five kilometers or less” 12 “5-10 kms” 13 “Ten or more kilometers” 19 “Don't know”
# 11 “Five kilometers or less” 12 “5-10 kms” 13 “Ten or more kilometers” 19 “Don't know”
# None
# 21 “Less than 30 minutes” 22 “More than 30 minutes” 29 “Don’t know”
# 21 “Less than 30 minutes” 22 “More than 30 minutes” 29 “Don’t know”
# 21 “Less than 30 minutes” 22 “More than 30 minutes” 29 “Don’t know”
# 21 “Less than 30 minutes” 22 “More than 30 minutes” 29 “Don’t know”
# 21 “Less than 30 minutes” 22 “More than 30 minutes” 29 “Don’t know”
# None
# 31 “Ten minutes or less” 32 “10-30 minutes” 33 “More than 30 minutes” 39 “Don’t know”
# 31 “Ten minutes or less” 32 “10-30 minutes” 33 “More than 30 minutes” 39 “Don’t know”
# 31 “Ten minutes or less” 32 “10-30 minutes” 33 “More than 30 minutes” 39 “Don’t know”
# 31 “Ten minutes or less” 32 “10-30 minutes” 33 “More than 30 minutes” 39 “Don’t know”
# 31 “Ten minutes or less” 32 “10-30 minutes” 33 “More than 30 minutes” 39 “Don’t know”
# 0 “No” 1 “Yes” 99 “Don't Know”
# 1 “Did not seek medical care” 2 “Received medical care but was not hospitalized” 3 “Was hospitalized” 99 “Don’t know/ not sure”
# 0 “No” 1 “Yes” 99 “Don't Know”
# 0 “No” 1 “Yes, completed primary doses and with at least one booster dose” 2 “Yes, completed primary doses” 3 “Yes, one dose”
# 1 “Very easy” 2 “Somewhat easy” 3 “Somewhat difficult” 4 “Very difficult” 99 “Don’t know/ not sure”
# 1 “Strongly agree” 2 “Agree” 3 “Neither agree nor disagree” 4 “Disagree” 5 “Strongly disagre” 99 “Don’t know/ not sure”
# 1 “Health center/ barangay health station” 2 “Barangay hall” 3 “Gym/ covered courts/ public open space” 4 “Malls/ closed public places” 5 “At my workplace” 6 “Hospital” 7 “School” 8 “Add: Own home” 98 “Other (Specify)” 99 “Don't Know”
# None
# 1 “Not at all” 2 “Likely” 3 “Somewhat likely” 4 “Extremely likely” 99 “Don't Know”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes” 99 “Don't know”
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes” 2 “Maybe” 99 “Don't know”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# None
# 0 “No” 1 “Yes” 99 “Don't Know”
# 1 “Did not seek medical care” 2 “Received medical care but was not hospitalized” 3 “Was hospitalized” 99 “Don’t know/ not sure”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 1 “Very easy” 2 “Somewhat easy” 3 “Somewhat difficult” 4 “Very difficult” 99 “Don’t know/ not sure”
# 1 “Health center/ barangay health station” 2 “Barangay hall” 3 “Gym/ covered courts/ public open space” 4 “Malls/ closed public places” 5 “At my workplace” 6 “Hospital” 7 “School” 8 “Add: Home” 9 “Add: Church” 10 “Add: Camp (police)” 98 “Other (Specify)” 99 “Don't Know”
# None
# 0 “No” 1 “Yes” 2 “Maybe” 99 “Don't Know”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# 0 “No” 1 “Yes” 2 “Maybe” 99 “Don't Know”
# 1 “Did not seek medical care” 2 “Received medical care but was not hospitalized” 3 “Was hospitalized” 99 “Don’t know/ not sure”
# 0 “No” 1 “Yes, completed primary doses” 2 “Yes, first dose”
# 0 “No” 1 “Yes” 2 “Maybe” 99 “Don't Know”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes” 2 “Maybe” 99 “Don't Know”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# None
# 0 "Nothing"
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# 1 “Shaking hands of infected person and then touching own's face” 2 “When infected person sneezes, coughs or talks” 3 “Through mosquito bites” 4 “Touching an infected surface and then touching own's face” 5 “Improper ventilation/through the air” 6 “Add: Crowded room/place” 7 “Add: Not following the health protocol” 98 “Other (Specify)” 99 “Don't Know”
# None
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# None
# 1 “All people” 2 “Most people” 3 “At least half of the people” 4 “Less than half of the people” 5 “None of the people” 99 “Don't Know”
# 1 “All people” 2 “Most people” 3 “At least half of the people” 4 “Less than half of the people” 5 “None of the people” 99 “Don't Know”
# 1 “All people” 2 “Most people” 3 “At least half of the people” 4 “Less than half of the people” 5 “None of the people” 99 “Don't Know”
# 1 “Not at all” 2 “Likely” 3 “Somewhat likely” 4 “Extremely likely”
# None
# 1 “Agree” 2 “Disagree” 99 “Don’t know/ not sure”
# 1 “Agree” 2 “Disagree” 99 “Don’t know/ not sure”
# 1 “Agree” 2 “Disagree” 99 “Don’t know/ not sure”
# 1 “Agree” 2 “Disagree” 99 “Don’t know/ not sure”
# 1 “Agree” 2 “Disagree” 99 “Don’t know/ not sure”
# 1 “Agree” 2 “Disagree” 99 “Don’t know/ not sure”
# 1 “Agree” 2 “Disagree” 99 “Don’t know/ not sure”
# 1 “Agree” 2 “Disagree” 99 “Don’t know/ not sure”
# 1 “Agree” 2 “Disagree” 99 “Don’t know/ not sure”
# 1 “Agree” 2 “Disagree” 99 “Don’t know/ not sure”
# 1 “Agree” 2 “Disagree” 99 “Don’t know/ not sure”
# 1 “Agree” 2 “Disagree” 99 “Don’t know/ not sure”
# 1 “Agree” 2 “Disagree” 99 “Don’t know/ not sure”
# 1 “Agree” 2 “Disagree” 99 “Don’t know/ not sure”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# None
# 1 “Never” 2 “Less than once a week” 3 “Less than once a week” 4 “Almost every day” 5 “Everyday”
# 1 “Never” 2 “Less than once a week” 3 “Less than once a week” 4 “Almost every day” 5 “Everyday”
# 1 “Never” 2 “Less than once a week” 3 “Less than once a week” 4 “Almost every day” 5 “Everyday”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# 1 “Never” 2 “Less than once a week” 3 “At least once a week” 4 “Almost every day” 5 “Everyday”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# 1 “Never” 2 “Less than once a week” 3 “Less than once a week” 4 “Almost every day” 5 “Everyday”
# 0 “No” 1 “Yes”
# None
# 1 “Never” 2 “Seldom” 3 “Frequently”
# 1 “Never” 2 “Seldom” 3 “Frequently”
# 1 “Never” 2 “Seldom” 3 “Frequently”
# 1 “Never” 2 “Seldom” 3 “Frequently”
# 1 “Never” 2 “Seldom” 3 “Frequently”
# 1 “Never” 2 “Seldom” 3 “Frequently”
# 1 “Never” 2 “Seldom” 3 “Frequently”
# 1 “Never” 2 “Seldom” 3 “Frequently”
# 1 “Never” 2 “Seldom” 3 “Frequently”
# 1 “Never” 2 “Seldom” 3 “Frequently”
# 1 “Never” 2 “Seldom” 3 “Frequently”
# 1 “Never” 2 “Seldom” 3 “Frequently”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 1 “Facebook” 2 “Twitter” 3 “Instagram” 4 “LinkedIn” 5 “WhatsApp” 6 “Facebook Messenger” 7 “Viber” 8 “TikTok” 9 “Add: YouTube” 98 “Other (specify)”
# None
# None
# 1 “Never” 2 “Seldom” 3 “Frequently”
# 1 “Never” 2 “Seldom” 3 “Frequently”
# 1 “Never” 2 “Seldom” 3 “Frequently”
# 1 “Never” 2 “Seldom” 3 “Frequently”
# 1 “Never” 2 “Seldom” 3 “Frequently”
# 1 “Never” 2 “Seldom” 3 “Frequently”
# 1 “Never” 2 “Seldom” 3 “Frequently”
# 1 “Never” 2 “Seldom” 3 “Frequently”
# 1 “Never” 2 “Seldom” 3 “Frequently”
# 1 “Never” 2 “Seldom” 3 “Frequently”
# None
# 1 “All” 2 “Most” 3 “At least half” 4 “Less than half” 5 “None”
# 1 “All” 2 “Most” 3 “At least half” 4 “Less than half” 5 “None”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes” 2 “Recalled with logo aid”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes, sought more information about COVID-19” 2 “Yes, followed minimum public health standards” 3 “Yes, went to the health facility/ LGU to schedule vaccination”
# None
# 0 “No” 1 “Yes” 2 “Recalled with logo aid”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes, sought more information about COVID-19” 2 “Yes, went to the health facility/LGU to schedule vaccination” 3 “Yes, went to get vaccinated/have booster dose”
# 0 “No” 1 “Yes” 2 “Recalled with logo”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes, sought more information about COVID-19” 2 “Yes, followed COVID-19 prevention practices”
# 0 “No” 1 “Yes” 2 “Recalled with logo aid”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes, sought more information about COVID-19” 2 “Yes, followed COVID-19 prevention practices”
# 0 “No” 1 “Yes” 2 “Recalled with logo aid”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes, sought more information about COVID-19” 2 “Yes, followed COVID-19 prevention practices” 3 “Yes, went to the health facility/LGU to schedule vaccination” 4 “Yes, went to get vaccinated/have booster dose”
# 0 “No” 1 “Yes” 2 “Recalled with logo aid”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes, sought more information about COVID-19” 2 “Yes, went to the health facility/LGU to schedule vaccination” 3 “Yes, went to get vaccinated/have booster dose”
# 0 “No” 1 “Yes” 2 “Recalled with logo aid”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes, sought more information about COVID-19” 2 “Yes, went to the health facility/LGU to schedule vaccination” 3 “Yes, went to get vaccinated/have booster dose”
# 0 “No” 1 “Yes” 2 “Recalled with logo aid”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes, sought more information about COVID-19” 2 “Yes, went to the health facility/LGU to schedule vaccination” 3 “Yes, went to get vaccinaed/have booster dose”
# 0 “No” 1 “Yes” 2 “Recalled with logo aid”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes, sought more information about COVID-19” 2 “Yes, followed COVID-19 prevention practices” 3 “Yes, went to the health facility/LGU to schedule vaccination” 4 “Yes, went to get vaccinated/have booster dose”
# 0 “No” 1 “Yes” 2 “Recalled with logo aid”
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# None
# 0 “No” 1 “Yes”
# None
# None
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes”
# 0 “No” 1 “Yes, sought more information about COVID-19” 2 “Yes, went to the health facility/LGU to schedule vaccination” 3 “Yes, went to get vaccinated/have booster dose”
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# 11 “Head of Household” 12 “Wife/Husband of head of household” 13 “Child” 14 “Son or Daughter in Law” 15 “Grandchild” 16 “Parent” 17 “Parent in Law” 18 “Sibling” 19 “Relatives” 20 “Adopted Child” 21 “Step child” 22 “Not Related” 98 “Don't know”
# None
# 1 “M” 2 “F”
# 1 “Single” 2 “Married” 3 “Widowed” 4 “Separated”
# None
# None
# None
# 11 “Head of Household” 12 “Wife/Husband of head of household” 13 “Child” 14 “Son or Daughter in Law” 15 “Grandchild” 16 “Parent” 17 “Parent in Law” 18 “Sibling” 19 “Relatives” 20 “Adopted Child” 21 “Step child” 22 “Not Related” 98 “Don't know”
# None
# 1 “M” 2 “F”
# 1 “Single” 2 “Married” 3 “Widowed” 4 “Separated”
# None
# None
# None
# 11 “Head of Household” 12 “Wife/Husband of head of household” 13 “Child” 14 “Son or Daughter in Law” 15 “Grandchild” 16 “Parent” 17 “Parent in Law” 18 “Sibling” 19 “Relatives” 20 “Adopted Child” 21 “Step child” 22 “Not Related” 98 “Don't know”
# None
# 1 “M” 2 “F”
# 1 “Single” 2 “Married” 3 “Widowed” 4 “Separated”
# None
# None
# None
# 11 “Head of Household” 12 “Wife/Husband of head of household” 13 “Child” 14 “Son or Daughter in Law” 15 “Grandchild” 16 “Parent” 17 “Parent in Law” 18 “Sibling” 19 “Relatives” 20 “Adopted Child” 21 “Step child” 22 “Not Related” 98 “Don't know”
# None
# 1 “M” 2 “F”
# 1 “Single” 2 “Married” 3 “Widowed” 4 “Separated”
# None
# None
# None
# 11 “Head of Household” 12 “Wife/Husband of head of household” 13 “Child” 14 “Son or Daughter in Law” 15 “Grandchild” 16 “Parent” 17 “Parent in Law” 18 “Sibling” 19 “Relatives” 20 “Adopted Child” 21 “Step child” 22 “Not Related” 98 “Don't know”
# None
# 1 “M” 2 “F”
# 1 “Single” 2 “Married” 3 “Widowed” 4 “Separated”
# None
# None
# None
# 11 “Head of Household” 12 “Wife/Husband of head of household” 13 “Child” 14 “Son or Daughter in Law” 15 “Grandchild” 16 “Parent” 17 “Parent in Law” 18 “Sibling” 19 “Relatives” 20 “Adopted Child” 21 “Step child” 22 “Not Related” 98 “Don't know”
# None
# 1 “M” 2 “F”
# 1 “Single” 2 “Married” 3 “Widowed” 4 “Separated”
# None
# None
# None
# 11 “Head of Household” 12 “Wife/Husband of head of household” 13 “Child” 14 “Son or Daughter in Law” 15 “Grandchild” 16 “Parent” 17 “Parent in Law” 18 “Sibling” 19 “Relatives” 20 “Adopted Child” 21 “Step child” 22 “Not Related” 98 “Don't know”
# None
# 1 “M” 2 “F”
# 1 “Single” 2 “Married” 3 “Widowed” 4 “Separated”
# None
# None
# None
# 11 “Head of Household” 12 “Wife/Husband of head of household” 13 “Child” 14 “Son or Daughter in Law” 15 “Grandchild” 16 “Parent” 17 “Parent in Law” 18 “Sibling” 19 “Relatives” 20 “Adopted Child” 21 “Step child” 22 “Not Related” 98 “Don't know”
# None
# 1 “M” 2 “F”
# 1 “Single” 2 “Married” 3 “Widowed” 4 “Separated”
# None
# None
# None
# 11 “Head of Household” 12 “Wife/Husband of head of household” 13 “Child” 14 “Son or Daughter in Law” 15 “Grandchild” 16 “Parent” 17 “Parent in Law” 18 “Sibling” 19 “Relatives” 20 “Adopted Child” 21 “Step child” 22 “Not Related” 98 “Don't know”
# None
# 1 “M” 2 “F”
# 1 “Single” 2 “Married” 3 “Widowed” 4 “Separated”
# None
# None
# None
# 11 “Head of Household” 12 “Wife/Husband of head of household” 13 “Child” 14 “Son or Daughter in Law” 15 “Grandchild” 16 “Parent” 17 “Parent in Law” 18 “Sibling” 19 “Relatives” 20 “Adopted Child” 21 “Step child” 22 “Not Related” 98 “Don't know”
# None
# 1 “M” 2 “F”
# 1 “Single” 2 “Married” 3 “Widowed” 4 “Separated”
# None
# None
# None
# 11 “Head of Household” 12 “Wife/Husband of head of household” 13 “Child” 14 “Son or Daughter in Law” 15 “Grandchild” 16 “Parent” 17 “Parent in Law” 18 “Sibling” 19 “Relatives” 20 “Adopted Child” 21 “Step child” 22 “Not Related” 98 “Don't know”
# None
# 1 “M” 2 “F”
# 1 “Single” 2 “Married” 3 “Widowed” 4 “Separated”
# None
# None
# None
# 11 “Head of Household” 12 “Wife/Husband of head of household” 13 “Child” 14 “Son or Daughter in Law” 15 “Grandchild” 16 “Parent” 17 “Parent in Law” 18 “Sibling” 19 “Relatives” 20 “Adopted Child” 21 “Step child” 22 “Not Related” 98 “Don't know”
# None
# 1 “M” 2 “F”
# 1 “Single” 2 “Married” 3 “Widowed” 4 “Separated”
# None
# None
# None
# 11 “Head of Household” 12 “Wife/Husband of head of household” 13 “Child” 14 “Son or Daughter in Law” 15 “Grandchild” 16 “Parent” 17 “Parent in Law” 18 “Sibling” 19 “Relatives” 20 “Adopted Child” 21 “Step child” 22 “Not Related” 98 “Don't know”
# None
# 1 “M” 2 “F”
# 1 “Single” 2 “Married” 3 “Widowed” 4 “Separated”
# None
# None
# None
# 11 “Head of Household” 12 “Wife/Husband of head of household” 13 “Child” 14 “Son or Daughter in Law” 15 “Grandchild” 16 “Parent” 17 “Parent in Law” 18 “Sibling” 19 “Relatives” 20 “Adopted Child” 21 “Step child” 22 “Not Related” 98 “Don't know”
# None
# 1 “M” 2 “F”
# 1 “Single” 2 “Married” 3 “Widowed” 4 “Separated”
# None
# None
# None
# 11 “Head of Household” 12 “Wife/Husband of head of household” 13 “Child” 14 “Son or Daughter in Law” 15 “Grandchild” 16 “Parent” 17 “Parent in Law” 18 “Sibling” 19 “Relatives” 20 “Adopted Child” 21 “Step child” 22 “Not Related” 98 “Don't know”
# None
# 1 “M” 2 “F”
# 1 “Single” 2 “Married” 3 “Widowed” 4 “Separated”
# None
# None
# None
# 11 “Head of Household” 12 “Wife/Husband of head of household” 13 “Child” 14 “Son or Daughter in Law” 15 “Grandchild” 16 “Parent” 17 “Parent in Law” 18 “Sibling” 19 “Relatives” 20 “Adopted Child” 21 “Step child” 22 “Not Related” 98 “Don't know”
# None
# 1 “M” 2 “F”
# 1 “Single” 2 “Married” 3 “Widowed” 4 “Separated”
# None
# None
# None
# 11 “Head of Household” 12 “Wife/Husband of head of household” 13 “Child” 14 “Son or Daughter in Law” 15 “Grandchild” 16 “Parent” 17 “Parent in Law” 18 “Sibling” 19 “Relatives” 20 “Adopted Child” 21 “Step child” 22 “Not Related” 98 “Don't know”
# None
# 1 “M” 2 “F”
# 1 “Single” 2 “Married” 3 “Widowed” 4 “Separated”
# None
# None
# None
# 11 “Head of Household” 12 “Wife/Husband of head of household” 13 “Child” 14 “Son or Daughter in Law” 15 “Grandchild” 16 “Parent” 17 “Parent in Law” 18 “Sibling” 19 “Relatives” 20 “Adopted Child” 21 “Step child” 22 “Not Related” 98 “Don't know”
# None
# 1 “M” 2 “F”
# 1 “Single” 2 “Married” 3 “Widowed” 4 “Separated”
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
# Getting a list of unique response options
# These will be the values for the key:value pairs
responses = []

with open(csv_file, 'r') as f:
    reader = csv.reader(f, delimiter = ',')
    header = next(reader)
    for line in reader:
        if line[2] not in responses:
            responses.append(line[2])
            
print (responses)
# Out:
# ['None', '1 “National Capital Region” 2 “Cordillera Autonomous Region” 3 “Central Luzon” 4 “MIMAROPA” 5 “Central Visayas” 6 “Western Visayas” 7 “Northern Mindanao” 8 “Bangsamoro Autonomous Region in Muslim Mindanao”', '1 “Caloocan” 2 “Navotas” 3 “Valenzuela” 4 “Las Piñas” 5 “Makati” 6 “Muntinlupa” 7 “Parañaque” 8 “Pasay” 9 “Taguig” 10 “Manila” 11 “Mandaluyong” 12 “Marikina” 13 “Pasig” 14 “Quezon City” 15 “San Juan City” 16 “Ifugao” 17 “Pampanga” 18 “Palawan” 19 “Negros Oriental” 20 “Iloilo” 21 “Misamis Oriental” 22 “Basilan” 23 “Sulu” 24 “Maguindanao”', '1 “Caloocan” 2 “Navotas” 3 “Valenzuela” 4 “Las Piñas” 5 “Makati” 6 “Muntinlupa” 7 “Parañaque” 8 “Pasay” 9 “Taguig” 10 “Tondo” 11 “Santa Cruz” 12 “Intramuros” 13 “Santa Ana” 14 “Mandaluyong” 15 “Marikina” 16 “Pasig” 17 “Quezon City” 18 “San Juan” 19 “Alfonso Lista” 20 “Santa Ana” 21 “Lubao” 22 “Floridablanca” 23 “Magalang” 24 “City of San Fernando (capital)” 25 “City of Angeles” 26 “Linapacacn” 27 “Rizal” 28 “Narra” 29 “Mabinay” 30 “City of Tanjay” 31 “City of Bayawan” 32 “Jimalalud” 33 “City of Iloilo (Capital)” 34 “City of Passi” 35 “Tigbauan” 36 “Calinog” 37 “Salay” 38 “City of Cagayan de Oro (capital)” 39 “Lantawan” 40 “Old Panamao” 41 “Talipao” 42 “Siasi” 43 “Datu Unsay” 44 “Kabuntalan Tumbao” 45 “Sultan Kudarat”', '1 “Barangay 88” 2 “Barangay 171” 3 “Barangay 176” 4 “Barangay 188” 5 “Sipac-Almacen” 6 “Gen. T. De Leon” 7 “Ugong” 8 “Pamplona Tres” 9 “Palanan” 10 “Alabang” 11 “Sucat” 12 “Marcelo Green Village” 13 “Barangay 57” 14 “Tanyag” 15 “Ususan” 16 “South Signal Village” 17 “Barangay 142” 18 “Barangay 377” 19 “Barangay 658” 20 “Barangay 786” 21 “Namayan” 22 “Marikina Heights” 23 “Pinagbuhatan” 24 “Ugong” 25 “Bahay Toro” 26 “Donya Imelda” 27 “Matandang Balara” 28 “Ramon Magsaysay” 29 “South Triangle” 30 “Payatas” 31 “Ermitano” 32 “Pinto” 33 “Santo Rosario” 34 “Santo Cristo” 35 “San Nicolas” 36 “San Pedro II” 37 “San Nicolas” 38 “Pulung Maragul” 39 “Calibangbangan” 40 “Ransang” 41 “Panacan 2” 42 “Cansal-ing” 43 “San Miguel” 44 “Villasol” 45 “North Poblacion” 46 “San Antonio” 47 “Aglalana” 48 “Tan Pael” 49 “Simsiman” 50 “Gustilo” 51 “Inobulan” 52 “Puerto” 53 “Balulang” 54 “Canibungan” 55 “Tubig Gantang” 56 “Kabatuhan Bilaan” 57 “Siowing” 58 “Tuntungan” 59 “Buterin” 60 “Limbo”', '1 “Urban” 2 “Rural”', '1 “Female” 2 “Male”', '11 “Housewife” 12 “Civil Servant” 13 “Professional” 14 “Private Employee” 15 “Farmer / Owner of Farm” 16 “Fisherman/ Owner of Boat” 17 “Renting out boat / car/ motorcycle/ house” 18 “Entrepreneur / owner of a salon/car service/ sari-sari store” 19 “Trader” 20 “Day Labour / Agriculutural / Fishing / Driver” 21 “Honorarium Based worker” 22 “Student” 23 “Not working” 24 “Add: OFW” 98 “Other (Specify)”', '0 “No entry/response” 1 “Less than PHP 10,957 per month” 2 “PHP 10,957 – PHP 21,914” 3 “PHP 21,915 – PHP 43,828” 4 “PHP 43,829 – PHP 76,699” 5 “PHP 77,000 – PHP 131,483” 6 “PHP 131,484 – PHP 219,140” 7 “At least PHP 219,140”', '0 “No Religion” 1 “Roman Catholic” 2 “Protestant” 3 “Iglesia Ni Cristo” 4 “Aglipay” 5 “Islam” 6 “Add: Born Again Christian” 7 “Add: Seventh Day Adventist” 8 “Add: The Church of Jesus Christ of Latter-day Saints” 98 “Other (Specify)”', '0 “None” 1 “Some Primary” 2 “Completed Primary” 3 “Some Secondary” 4 “Completed Secondary” 5 “Higher Ed/ College/ University”', '0 “Never Married” 1 “Married” 2 “Living with someone as if Married” 3 “Separated” 4 “Widowed”', '0 “No” 1 “Yes”', '1 “Own house and lot or owner-like possession of house and lot” 2 “Own house, rent lot” 3 “Own house rent free lot with consent of owner” 4 “Own house rent free lot without consent of owner” 5 “Rent house/room including lot” 6 “Rent free house and lot with consent of owner” 7 “Rent free house and lot without consent of owner” 98 “Other (Specify)”', "11 “Five kilometers or less” 12 “5-10 kms” 13 “Ten or more kilometers” 19 “Don't know”", '21 “Less than 30 minutes” 22 “More than 30 minutes” 29 “Don’t know”', '31 “Ten minutes or less” 32 “10-30 minutes” 33 “More th ...

# %%
# Generating 100 labelids which will serve as the keys for the key:value pair
labelid = []
labelnum = 1
for x in range(1, 101):
    labelnum += 1
    res = ("labelname" + str(labelnum))
    labelid.append(res)
print(labelid[:10])
# Out:
# ['labelname2', 'labelname3', 'labelname4', 'labelname5', 'labelname6', 'labelname7', 'labelname8', 'labelname9', 'labelname10', 'labelname11']

# %% [markdown]
# Creating label dictionary by combining the label id (key) and responses (values)

# %%
labeldict = dict(zip(labelid, responses))
print (labeldict)
# Out:
# {'labelname2': 'None', 'labelname3': '1 “National Capital Region” 2 “Cordillera Autonomous Region” 3 “Central Luzon” 4 “MIMAROPA” 5 “Central Visayas” 6 “Western Visayas” 7 “Northern Mindanao” 8 “Bangsamoro Autonomous Region in Muslim Mindanao”', 'labelname4': '1 “Caloocan” 2 “Navotas” 3 “Valenzuela” 4 “Las Piñas” 5 “Makati” 6 “Muntinlupa” 7 “Parañaque” 8 “Pasay” 9 “Taguig” 10 “Manila” 11 “Mandaluyong” 12 “Marikina” 13 “Pasig” 14 “Quezon City” 15 “San Juan City” 16 “Ifugao” 17 “Pampanga” 18 “Palawan” 19 “Negros Oriental” 20 “Iloilo” 21 “Misamis Oriental” 22 “Basilan” 23 “Sulu” 24 “Maguindanao”', 'labelname5': '1 “Caloocan” 2 “Navotas” 3 “Valenzuela” 4 “Las Piñas” 5 “Makati” 6 “Muntinlupa” 7 “Parañaque” 8 “Pasay” 9 “Taguig” 10 “Tondo” 11 “Santa Cruz” 12 “Intramuros” 13 “Santa Ana” 14 “Mandaluyong” 15 “Marikina” 16 “Pasig” 17 “Quezon City” 18 “San Juan” 19 “Alfonso Lista” 20 “Santa Ana” 21 “Lubao” 22 “Floridablanca” 23 “Magalang” 24 “City of San Fernando (capital)” 25 “City of Angeles” 26 “Linapacacn” 27 “Rizal” 28 “Narra” 29 “Mabinay” 30 “City of Tanjay” 31 “City of Bayawan” 32 “Jimalalud” 33 “City of Iloilo (Capital)” 34 “City of Passi” 35 “Tigbauan” 36 “Calinog” 37 “Salay” 38 “City of Cagayan de Oro (capital)” 39 “Lantawan” 40 “Old Panamao” 41 “Talipao” 42 “Siasi” 43 “Datu Unsay” 44 “Kabuntalan Tumbao” 45 “Sultan Kudarat”', 'labelname6': '1 “Barangay 88” 2 “Barangay 171” 3 “Barangay 176” 4 “Barangay 188” 5 “Sipac-Almacen” 6 “Gen. T. De Leon” 7 “Ugong” 8 “Pamplona Tres” 9 “Palanan” 10 “Alabang” 11 “Sucat” 12 “Marcelo Green Village” 13 “Barangay 57” 14 “Tanyag” 15 “Ususan” 16 “South Signal Village” 17 “Barangay 142” 18 “Barangay 377” 19 “Barangay 658” 20 “Barangay 786” 21 “Namayan” 22 “Marikina Heights” 23 “Pinagbuhatan” 24 “Ugong” 25 “Bahay Toro” 26 “Donya Imelda” 27 “Matandang Balara” 28 “Ramon Magsaysay” 29 “South Triangle” 30 “Payatas” 31 “Ermitano” 32 “Pinto” 33 “Santo Rosario” 34 “Santo Cristo” 35 “San Nicolas” 36 “San Pedro II” 37 “San Nicolas” 38 “Pulung Maragul” 39 “Calibangbangan” 40 “Ransang” 41 “Panacan 2” 42 “Cansal-ing” 43 “San Miguel” 44 “Villasol” 45 “North Poblacion” 46 “San Antonio” 47 “Aglalana” 48 “Tan Pael” 49 “Simsiman” 50 “Gustilo” 51 “Inobulan” 52 “Puerto” 53 “Balulang” 54 “Canibungan” 55 “Tubig Gantang” 56 “Kabatuhan Bilaan” 57 “Siowing” 58 “Tuntungan” 59 “Buterin” 60 “Limbo”', 'labelname7': '1 “Urban” 2 “Rural”', 'labelname8': '1 “Female” 2 “Male”', 'labelname9': '11 “Housewife” 12 “Civil Servant” 13 “Professional” 14 “Private Employee” 15 “Farmer / Owner of Farm” 16 “Fisherman/ Owner of Boat” 17 “Renting out boat / car/ motorcycle/ house” 18 “Entrepreneur / owner of a salon/car service/ sari-sari store” 19 “Trader” 20 “Day Labour / Agriculutural / Fishing / Driver” 21 “Honorarium Based worker” 22 “Student” 23 “Not working” 24 “Add: OFW” 98 “Other (Specify)”', 'labelname10': '0 “No entry/response” 1 “Less than PHP 10,957 per month” 2 “PHP 10,957 – PHP 21,914” 3 “PHP 21,915 – PHP 43,828” 4 “PHP 43,829 – PHP 76,699” 5 “PHP 77,000 – PHP 131,483” 6 “PHP 131,484 – PHP 219,140” 7 “At least PHP 219,140”', 'labelname11': '0 “No Religion” 1 “Roman Catholic” 2 “Protestant” 3 “Iglesia Ni Cristo” 4 “Aglipay” 5 “Islam” 6 “Add: Born Again Christian” 7 “Add: Seventh Day Adventist” 8 “Add: The Church of Jesus Christ of Latter-day Saints” 98 “Other (Specify)”', 'labelname12': '0 “None” 1 “Some Primary” 2 “Completed Primary” 3 “Some Secondary” 4 “Completed Secondary” 5 “Higher Ed/ College/ University”', 'labelname13': '0 “Never Married” 1 “Married” 2 “Living with someone as if Married” 3 “Separated” 4 “Widowed”', 'labelname14': '0 “No” 1 “Yes”', 'labelname15': '1 “Own house and lot or owner-like possession of house and lot” 2 “Own house, rent lot” 3 “Own house rent free lot with consent of owner” 4 “Own house rent free lot without consent of owner” 5 “Rent house/room including lot” 6 “Rent free house and lot with consent of owner” 7 “Rent free house and lot without consent of owner” 98 “Other (Specify)”', 'labelname16':  ...

# %% [markdown]
# ## Coverting codebook to STATA syntax
#
# We see from the above output that our top row has 3 columns.
#
# 1) Variable, 2) Item, and  3) Response Options
#
# <i><b>Variable</i></b> contains the variable name of our dataset [index 0]
#
# <i><b>Item</i></b> contains the question item [index 1]
#
# <i><b>Response Options</i></b> contains the response options for each question item [index 2]
# <br><br><br>
# We will use these three pieces of information to create STATA snytax that does the following:
#
# 1) define the response options using `response options` column.
#
# 2) Label the variables names and values using the `variable` and `item` columns.

# %%
# 1) Defining the response options
print ("*DEFINING LABELS FOR EACH UNIQUE RESPONSE OPTION")
print ("")
for x in labeldict:
    print ("label define", x, str(labeldict[x]))
    print ("")
print ("")
print ("")
# Out:
# *DEFINING LABELS FOR EACH UNIQUE RESPONSE OPTION
#
# label define labelname2 None
#
# label define labelname3 1 “National Capital Region” 2 “Cordillera Autonomous Region” 3 “Central Luzon” 4 “MIMAROPA” 5 “Central Visayas” 6 “Western Visayas” 7 “Northern Mindanao” 8 “Bangsamoro Autonomous Region in Muslim Mindanao”
#
# label define labelname4 1 “Caloocan” 2 “Navotas” 3 “Valenzuela” 4 “Las Piñas” 5 “Makati” 6 “Muntinlupa” 7 “Parañaque” 8 “Pasay” 9 “Taguig” 10 “Manila” 11 “Mandaluyong” 12 “Marikina” 13 “Pasig” 14 “Quezon City” 15 “San Juan City” 16 “Ifugao” 17 “Pampanga” 18 “Palawan” 19 “Negros Oriental” 20 “Iloilo” 21 “Misamis Oriental” 22 “Basilan” 23 “Sulu” 24 “Maguindanao”
#
# label define labelname5 1 “Caloocan” 2 “Navotas” 3 “Valenzuela” 4 “Las Piñas” 5 “Makati” 6 “Muntinlupa” 7 “Parañaque” 8 “Pasay” 9 “Taguig” 10 “Tondo” 11 “Santa Cruz” 12 “Intramuros” 13 “Santa Ana” 14 “Mandaluyong” 15 “Marikina” 16 “Pasig” 17 “Quezon City” 18 “San Juan” 19 “Alfonso Lista” 20 “Santa Ana” 21 “Lubao” 22 “Floridablanca” 23 “Magalang” 24 “City of San Fernando (capital)” 25 “City of Angeles” 26 “Linapacacn” 27 “Rizal” 28 “Narra” 29 “Mabinay” 30 “City of Tanjay” 31 “City of Bayawan” 32 “Jimalalud” 33 “City of Iloilo (Capital)” 34 “City of Passi” 35 “Tigbauan” 36 “Calinog” 37 “Salay” 38 “City of Cagayan de Oro (capital)” 39 “Lantawan” 40 “Old Panamao” 41 “Talipao” 42 “Siasi” 43 “Datu Unsay” 44 “Kabuntalan Tumbao” 45 “Sultan Kudarat”
#
# label define labelname6 1 “Barangay 88” 2 “Barangay 171” 3 “Barangay 176” 4 “Barangay 188” 5 “Sipac-Almacen” 6 “Gen. T. De Leon” 7 “Ugong” 8 “Pamplona Tres” 9 “Palanan” 10 “Alabang” 11 “Sucat” 12 “Marcelo Green Village” 13 “Barangay 57” 14 “Tanyag” 15 “Ususan” 16 “South Signal Village” 17 “Barangay 142” 18 “Barangay 377” 19 “Barangay 658” 20 “Barangay 786” 21 “Namayan” 22 “Marikina Heights” 23 “Pinagbuhatan” 24 “Ugong” 25 “Bahay Toro” 26 “Donya Imelda” 27 “Matandang Balara” 28 “Ramon Magsaysay” 29 “South Triangle” 30 “Payatas” 31 “Ermitano” 32 “Pinto” 33 “Santo Rosario” 34 “Santo Cristo” 35 “San Nicolas” 36 “San Pedro II” 37 “San Nicolas” 38 “Pulung Maragul” 39 “Calibangbangan” 40 “Ransang” 41 “Panacan 2” 42 “Cansal-ing” 43 “San Miguel” 44 “Villasol” 45 “North Poblacion” 46 “San Antonio” 47 “Aglalana” 48 “Tan Pael” 49 “Simsiman” 50 “Gustilo” 51 “Inobulan” 52 “Puerto” 53 “Balulang” 54 “Canibungan” 55 “Tubig Gantang” 56 “Kabatuhan Bilaan” 57 “Siowing” 58 “Tuntungan” 59 “Buterin” 60 “Limbo”
#
# label define labelname7 1 “Urban” 2 “Rural”
#
# label define labelname8 1 “Female” 2 “Male”
#
# label define labelname9 11 “Housewife” 12 “Civil Servant” 13 “Professional” 14 “Private Employee” 15 “Farmer / Owner of Farm” 16 “Fisherman/ Owner of Boat” 17 “Renting out boat / car/ motorcycle/ house” 18 “Entrepreneur / owner of a salon/car service/ sari-sari store” 19 “Trader” 20 “Day Labour / Agriculutural / Fishing / Driver” 21 “Honorarium Based worker” 22 “Student” 23 “Not working” 24 “Add: OFW” 98 “Other (Specify)”
#
# label define labelname10 0 “No entry/response” 1 “Less than PHP 10,957 per month” 2 “PHP 10,957 – PHP 21,914” 3 “PHP 21,915 – PHP 43,828” 4 “PHP 43,829 – PHP 76,699” 5 “PHP 77,000 – PHP 131,483” 6 “PHP 131,484 – PHP 219,140” 7 “At least PHP 219,140”
#
# label define labelname11 0 “No Religion” 1 “Roman Catholic” 2 “Protestant” 3 “Iglesia Ni Cristo” 4 “Aglipay” 5 “Islam” 6 “Add: Born Again Christian” 7 “Add: Seventh Day Adventist” 8 “Add: The Church of Jesus Christ of Latter-day Saints” 98 “Other (Specify)”
#
# label define labelname12 0 “None” 1 “Some Primary” 2 “Completed Primary” 3 “Some Secondary” 4 “Completed Secondary” 5 “Higher Ed/ College/ University”
#
# label define labelname13 0 “Never Married” 1 “Married” 2 “Living with someone as if Married” 3 “Separated” 4 “Widowed”
#
# label define labelname14 0 “No” 1 “Yes”
#
# label define labelname15 1 “Own house and lot or owner-like possession of house and lot” 2 “Own house, rent lot” 3 “Own house rent free lot with consent of owner” 4 “Own house rent free lot without consent of owner” 5 “Rent house/room including lot” 6 “Rent free house and lot with consent of owner” 7 “Rent free house and lot without consent of owner” 98 “Other (Specify)”
#
# label define labelname16 11 “Five kilometers or less” 12 “5-10 kms” 13 “Ten or more kilometers” 19 “Don't know”
#
# label define labelname17 21 “Less than 30 minutes” 22 “More than 30 minutes” 29 “Don’t know”
#
# label define labelname18 31 “Ten minutes or less” 32 “10-30 minutes” 33 “More than 30 minutes” 39 “Don’t know”
#
# label define labelname19 0 “No” 1 “Yes” 99 “Don't Know”
#
# label define labelname20 1 “Did not seek medical care” 2 “Received medical care but was not hospitalized” 3 “Was hospitalized” 99 “Don’t know/ not sure”
#
# label define labelname21 0 “No” 1 “Yes, completed primary doses and with at least one booster dose” 2 “Yes, completed primary doses” 3 “Yes, one dose”
#
# label define labelname22 1 “Very easy” 2 “Somewhat easy” 3 “Somewhat difficult” 4 “Very difficult” 99 “Don’t know/ not sure”
#
# label define labelname23 1 “Strongly agree” 2 “Agree” 3 “Neither agree nor disagree” 4 “Disagree” 5 “Strongly disagre” 99 “Don’t know/ not sure”
#
# label define labelname24 1 “Health center/ barangay health station” 2 “Barangay hall” 3 “Gym/ covered courts/ public open space” 4 “Malls/ closed public places” 5 “At my workplace” 6 “Hospital” 7 “School” 8 “Add: Own home” 98 “Other (Specify)” 99 “Don't Know”
#
# label define labelname25 1 “Not at all” 2 “Likely” 3 “Somewhat likely” 4 “Extremely likely” 99 “Don't Know”
#
# label define labelname26 0 “No” 1 “Yes” 99 “Don't know”
#
# label define labelname27 0 “No” 1 “Yes” 2 “Maybe” 99 “Don't know”
#
# label define labelname28 1 “Health center/ barangay health station” 2 “Barangay hall” 3 “Gym/ covered courts/ public open space” 4 “Malls/ closed public places” 5 “At my workplace” 6 “Hospital” 7 “School” 8 “Add: Home” 9 “Add: Church” 10 “Add: Camp (police)” 98 “Other (Specify)” 99 “Don't Know”
#
# label define labelname29 0 “No” 1 “Yes” 2 “Maybe” 99 “Don't Know”
#
# label define labelname30 0 “No” 1 “Yes, completed primary doses” 2 “Yes, first dose”
#
# label define labelname31 0 "Nothing"
#
# label define labelname32 1 “Shaking hands of infected person and then touching own's face” 2 “When infected person sneezes, coughs or talks” 3 “Through mosquito bites” 4 “Touching an infected surface and then touching own's face” 5 “Improper ventilation/through the air” 6 “Add: Crowded room/place” 7 “Add: Not following the health protocol” 98 “Other (Specify)” 99 “Don't Know”
#
# label define labelname33 1 “All people” 2 “Most people” 3 “At least half of the people” 4 “Less than half of the people” 5 “None of the people” 99 “Don't Know”
#
# label define labelname34 1 “Not at all” 2 “Likely” 3 “Somewhat likely” 4 “Extremely likely”
#
# label define labelname35 1 “Agree” 2 “Disagree” 99 “Don’t know/ not sure”
#
# label define labelname36 1 “Never” 2 “Less than once a week” 3 “Less than once a week” 4 “Almost every day” 5 “Everyday”
#
# label define labelname37 1 “Never” 2 “Less than once a week” 3 “At least once a week” 4 “Almost every day” 5 “Everyday”
#
# label define labelname38 1 “Never” 2 “Seldom” 3 “Frequently”
#
# label define labelname39 1 “Facebook” 2 “Twitter” 3 “Instagram” 4 “LinkedIn” 5 “WhatsApp” 6 “Facebook Messenger” 7 “Viber” 8 “TikTok” 9 “Add: YouTube” 98 “Other (specify)”
#
# label define labelname40 1 “All” 2 “Most” 3 “At least half” 4 “Less than half” 5 “None”
#
# label define labelname41 0 “No” 1 “Yes” 2 “Recalled with logo aid”
#
# label define labelname42 0 “No” 1 “Yes, sought more information about COVID-19” 2 “Yes, followed minimum public health standards” 3 “Yes, went to the health facility/ LGU to schedule vaccination”
#
# label define labelname43 0 “No” 1 “Yes, sought more information about COVID-19” 2 “Yes, went to the health facility/LGU to schedule vaccination” 3 “Yes, went to get vaccinated/have booster dose”
#
# label define labelname44 0 “No” 1 “Yes” 2 “Recalled with logo”
#
# label define labelname45 0 “No” 1 “Yes, sought more information about COVID-19” 2 “Yes, followed COVID-19 prevention practices”
#
# label define labelname46 0 “No” 1 “Yes, sought more information about COVID-19” 2 “Yes, followed COVID-19 prevention practices” 3 “Yes, went to the health facility/LGU to schedule vaccination” 4 “Yes, went to get vaccinated/have booster dose”
#
# label define labelname47 0 “No” 1 “Yes, sought more information about COVID-19” 2 “Yes, went to the health facility/LGU to schedule vaccination” 3 “Yes, went to get vaccinaed/have booster dose”
#
# label define labelname48 11 “Head of Household” 12 “Wife/Husband of head of household” 13 “Child” 14 “Son or Daughter in Law” 15 “Grandchild” 16 “Parent” 17 “Parent in Law” 18 “Sibling” 19 “Relatives” 20 “Adopted Child” 21 “Step child” 22 “Not Related” 98 “Don't know”
#
# label define labelname49 1 “M” 2 “F”
#
# label define labelname50 1 “Single” 2 “Married” 3 “Widowed” 4 “Separated”

# %%
print ("*** DATA LABELING AND TABULATION***")
print ("")
with open(csv_file, 'r') as f:
    reader = csv.reader(f, delimiter = ',')
    header = next(reader)
    for line in reader:
        labels = str(line[0])+"label" # making a label name for STATA
        print ("*", line[0], "data label")
        print ("label variable", line[0], '"%s"' % line[1])
        for keylist, valuelist in labeldict.items():
            if valuelist == str(line[2]) and str(line[2]) != "None": #if label column is not "None", we print a label value
                print ("label values", str(line[0]), keylist)
        if str(line[2]) != "None": print ("asdoc tab",line[0],", append") # run tabulations if the variable label column contains a label and does not containt the string "None"- this assumes that the variable is a categorical variable  
        if str(line[2]) == "None": print ("asdoc summarize",line[0],", append") # run summaries if the variable label column contains "None", and assumes the variable is numeric.
        print("")
# Out:
# *** DATA LABELING AND TABULATION***
#
# * casenum data label
# label variable casenum "Case number"
# asdoc summarize casenum , append
#
# * SubmissionDate data label
# label variable SubmissionDate "SubmissionDate"
# asdoc summarize SubmissionDate , append
#
# * valid_age data label
# label variable valid_age "valid_age"
# asdoc summarize valid_age , append
#
# * confirmation data label
# label variable confirmation "confirmation"
# asdoc summarize confirmation , append
#
# * name data label
# label variable name "name"
# asdoc summarize name , append
#
# * Signature data label
# label variable Signature "Signature"
# asdoc summarize Signature , append
#
# * Date data label
# label variable Date "Date"
# asdoc summarize Date , append
#
# * confirmation_2 data label
# label variable confirmation_2 "confirmation_2"
# asdoc summarize confirmation_2 , append
#
# * region data label
# label variable region "1. Region"
# label values region labelname3
# asdoc tab region , append
#
# * province data label
# label variable province "2. Province"
# label values province labelname4
# asdoc tab province , append
#
# * city_municipality data label
# label variable city_municipality "3. City/Municipality"
# label values city_municipality labelname5
# asdoc tab city_municipality , append
#
# * barangay data label
# label variable barangay "4. Barangay"
# label values barangay labelname6
# asdoc tab barangay , append
#
# * residence data label
# label variable residence "Add: Type of residence"
# label values residence labelname7
# asdoc tab residence , append
#
# * household_number data label
# label variable household_number "6. Household number"
# asdoc summarize household_number , append
#
# * hhmem_code data label
# label variable hhmem_code "Household member code"
# asdoc summarize hhmem_code , append
#
# * A01 data label
# label variable A01 "A01 Age of the respondent"
# asdoc summarize A01 , append
#
# * A02 data label
# label variable A02 "A02 Sex of the respondent"
# label values A02 labelname8
# asdoc tab A02 , append
#
# * A03 data label
# label variable A03 "A03 Main occupation (add category)"
# label values A03 labelname9
# asdoc tab A03 , append
#
# * A03_others data label
# label variable A03_others "A03 Main occupation, others"
# asdoc summarize A03_others , append
#
# * A04 data label
# label variable A04 "A04 What is the monthly household/ family income for your household?"
# label values A04 labelname10
# asdoc tab A04 , append
#
# * A05 data label
# label variable A05 "A05 Religion (add category)"
# label values A05 labelname11
# asdoc tab A05 , append
#
# * A05_others data label
# label variable A05_others "A05 Religion, others"
# asdoc summarize A05_others , append
#
# * A06 data label
# label variable A06 "A06 Education"
# label values A06 labelname12
# asdoc tab A06 , append
#
# * A07 data label
# label variable A07 "A07 Marital Status"
# label values A07 labelname13
# asdoc tab A07 , append
#
# * A08 data label
# label variable A08 "A08 Do you have a child between the ages of 5 and 17 years for whom you are the parent or primary caregiver?"
# label values A08 labelname14
# asdoc tab A08 , append
#
# * A09 data label
# label variable A09 "A09 Do you have a child less than five years old for whom you are the parent or primary caregiver?"
# label values A09 labelname14
# asdoc tab A09 , append
#
# * A10 data label
# label variable A10 "A10 Do you have a member of the family who is over 59 years of age living in your home?"
# label values A10 labelname14
# asdoc tab A10 , append
#
# * A11 data label
# label variable A11 "A11 Do you own your home?"
# label values A11 labelname15
# asdoc tab A11 , append
#
# * A11_others data label
# label variable A11_others "A11 Do you own your home ? | others"
# asdoc summarize A11_others , append
#
# * A12 data label
# label variable A12 "A12 How many people live in this house?"
# asdoc summarize A12 , append
#
# * A13 data label
# label variable A13 "A13 Does your household have…..?"
# asdoc summarize A13 , append
#
# * A13_A data label
# label variable A13_A "A13A Does your household have…..? Electricity"
# label values A13_A labelname14
# asdoc tab A13_A , append
#
# * A13_B data label
# label variable A13_B "A13B Does your household have…..? Radio"
# label values A13_B labelname14
# asdoc tab A13_B , append
#
# * A13_C data label
# label variable A13_C "A13C Does your household have…..? Color television"
# label values A13_C labelname14
# asdoc tab A13_C , append
#
# * A13_D data label
# label variable A13_D "A13D Does your household have…..? Cable services"
# label values A13_D labelname14
# asdoc tab A13_D , append
#
# * A13_E data label
# label variable A13_E "A13E Does your household have…..? Internet access"
# label values A13_E labelname14
# asdoc tab A13_E , append
#
# * A13_F data label
# label variable A13_F "A13F Does your household have…..? Telephone"
# label values A13_F labelname14
# asdoc tab A13_F , append
#
# * A13_G data label
# label variable A13_G "A13G Does your household have…..? Mobile phone"
# label values A13_G labelname14
# asdoc tab A13_G , append
#
# * A13_H data label
# label variable A13_H "A13H Does your household have…..? Smart phones"
# label values A13_H labelname14
# asdoc tab A13_H , append
#
# * A13_I data label
# label variable A13_I "A13I Does your household have…..? Computer or laptop"
# label values A13_I labelname14
# asdoc tab A13_I , append
#
# * A13_J data label
# label variable A13_J "A13J Does your household have…..? Refrigerator"
# label values A13_J labelname14
# asdoc tab A13_J , append
#
# * A13_K data label
# label variable A13_K "A13K Does your household have…..? Washing machine"
# label values A13_K labelname14
# asdoc tab A13_K , append
#
# * A13_L data label
# label variable A13_L "A13L Does your household have…..? Bicycle"
# label values A13_L labelname14
# asdoc tab A13_L , append
#
# * A13_M data label
# label variable A13_M "A13M Does your household have…..? Motorcycle"
# label values A13_M labelname14
# asdoc tab A13_M , append
#
# * A13_N data label
# label variable A13_N "A13N Does your household have…..? Car/Truck"
# label values A13_N labelname14
# asdoc tab A13_N , append
#
# * A13_O data label
# label variable A13_O "A13O Does your household have…..? Boat"
# label values A13_O labelname14
# asdoc tab A13_O , append
#
# * A14 data label
# label variable A14 "A14 How many cell phones does your household have?"
# asdoc summarize A14 , append
#
# * A15 data label
# label variable A15 "A15 Does your household own any livestock, herds, other farm animals, or poultry?"
# label values A15 labelname14
# asdoc tab A15 , append
#
# * A16 data label
# label variable A16 "A16 Is your household or any member of your household a beneficiary of the Pantawid Pamilyang Pilipino Program (4Ps)?"
# label values A16 labelname14
# asdoc tab A16 , append
#
# * A17_A_Distance data label
# label variable A17_A_Distance "A17 How far from your house are the following below and how long does it take to get there by walking, and by car/motorbike/bus? Distance: A) Nearest government hospital/health center"
# label values A17_A_Distance labelname16
# asdoc tab A17_A_Distance , append
#
# * A17_B_Distance data label
# label variable A17_B_Distance "A17 How far from your house are the following below and how long does it take to get there by walking, and by car/motorbike/bus? Distance: B) Nearest private hospital/clinic"
# label values A17_B_Distance labelname16
# asdoc tab A17_B_Distance , append
#
# * A17_C_Distance data label
# label variable A17_C_Distance "A17 How far from your house are the following below and how long does it take to get there by walking, and by car/motorbike/bus? Distance: C) Nearest pharmacy/drug store"
# label values A17_C_Distance labelname16
# asdoc tab A17_C_Distance , append
#
# * A17_D_Distance data label
# label variable A17_D_Distance "A17 How far from your house are the following below and how long does it take to get there by walking, and by car/motorbike/bus? Distance: D) Nearest community health worker"
# label values A17_D_Distance labelname16
# asdoc tab A17_D_Distance , append
#
# * A17_E_Distance data label
# label variable A17_E_Distance "A17 How far from your house are the following below and how long does it take to get there by walking, and by car/motorbike/bus? Distance: E) Nearest COVID Vaccination site"
# label values A17_E_Distance labelname16
# asdoc tab A17_E_Distance , append
#
# * A17_A_TimeWalking data label
# label variable A17_A_TimeWalking "A17 How far from your house are the following below and how long does it take to get there by walking, and by car/motorbike/bus? Time Walking: A) Nearest government hospital/health center"
# label values A17_A_TimeWalking labelname17
# asdoc tab A17_A_TimeWalking , append
#
# * A17_B_TimeWalking data label
# label variable A17_B_TimeWalking "A17 How far from your house are the following below and how long does it take to get there by walking, and by car/motorbike/bus? Time Walking: B) Nearest private hospital/clinic"
# label values A17_B_TimeWalking labelname17
# asdoc tab A17_B_TimeWalking , append
#
# * A17_C_TimeWalking data label
# label variable A17_C_TimeWalking "A17 How far from your house are the following below and how long does it take to get there by walking, and by car/motorbike/bus? Time Walking: C) Nearest pharmacy/drug store"
# label values A17_C_TimeWalking labelname17
# asdoc tab A17_C_TimeWalking , append
#
# * A17_D_TimeWalking data label
# label variable A17_D_TimeWalking "A17 How far from your house are the following below and how long does it take to get there by walking, and by car/motorbike/bus? Time Walking: D) Nearest community health worker"
# label values A17_D_TimeWalking labelname17
# asdoc tab A17_D_TimeWalking , append
#
# * A17_E_TimeWalking data label
# label variable A17_E_TimeWalking "A17 How far from your house are the following below and how long does it take to get there by walking, and by car/motorbike/bus? Time Walking: E) Nearest COVID Vaccination site"
# label values A17_E_TimeWalking labelname17
# asdoc tab A17_E_TimeWalking , append
#
# * A17_A_ByCar data label
# label variable A17_A_ByCar "A17 How far from your house are the following below and how long does it take to get there by walking, and by car/motorbike/bus? Time by Car/Motorbike/Bus: A) Nearest government hospital/health center"
# label values A17_A_ByCar labelname18
# asdoc tab A17_A_ByCar , append
#
# * A17_B_ByCar data label
# label variable A17_B_ByCar "A17 How far from your house are the following below and how long does it take to get there by walking, and by car/motorbike/bus? Time by Car/Motorbike/Bus: B) Nearest private hospital/clinic"
# label values A17_B_ByCar labelname18
# asdoc tab A17_B_ByCar , append
#
# * A17_C_ByCar data label
# label variable A17_C_ByCar "A17 How far from your house are the following below and how long does it take to get there by walking, and by car/motorbike/bus? Time by Car/Motorbike/Bus: C) Nearest pharmacy/drug store"
# label values A17_C_ByCar labelname18
# asdoc tab A17_C_ByCar , append
#
# * A17_D_ByCar data label
# label variable A17_D_ByCar "A17 How far from your house are the following below and how long does it take to get there by walking, and by car/motorbike/bus? Time by Car/Motorbike/Bus: D) Nearest community health worker"
# label values A17_D_ByCar labelname18
# asdoc tab A17_D_ByCar , append
#
# * A17_E_ByCar data label
# label variable A17_E_ByCar "A17 How far from your house are the following below and how long does it take to get there by walking, and by car/motorbike/bus? Time by Car/Motorbike/Bus: E) Nearest COVID Vaccination site"
# label values A17_E_ByCar labelname18
# asdoc tab A17_E_ByCar , append
#
# * B1 data label
# label variable B1 "B1 To your knowledge, have you had COVID-19?"
# label values B1 labelname19
# asdoc tab B1 , append
#
# * B2 data label
# label variable B2 "B2 Describe the level of care you received."
# label values B2 labelname20
# asdoc tab B2 , append
#
# * B3 data label
# label variable B3 "B3 Do you personally know anyone in your family, group of friends, or community networks who became seriously ill or died as a result of COVID-19?"
# label values B3 labelname19
# asdoc tab B3 , append
#
# * B4 data label
# label variable B4 "B4 Have you received the COVID-19 vaccine? [3 dose: 2 doses pfizer/astra/sinovac or 1 dose janssen/gamaleya sputnik light plus one booster); primary dose (2 doses pfizer/ astra/sinovac or 1 dose janssen/gamaleya sputnik light); 1 dose of pfizer/ astra/sin"
# label values B4 labelname21
# asdoc tab B4 , append
#
# * B5 data label
# label variable B5 "B5 How easy was it for you to get a COVID-19 vaccine for yourself?"
# label values B5 labelname22
# asdoc tab B5 , append
#
# * B6 data label
# label variable B6 "B6 Do you feel information about your vaccine appointments was communicated clearly and effectively?"
# label values B6 labelname23
# asdoc tab B6 , append
#
# * B7 data label
# label variable B7 "B7 Where did you receive the most recent dose of COVID-19 vaccine? (add category)"
# label values B7 labelname24
# asdoc tab B7 , append
#
# * B7_others data label
# label variable B7_others "B7 Where did you receive the most recent dose of COVID-19 vaccine? Others"
# asdoc summarize B7_others , append
#
# * B8 data label
# label variable B8 "B8 How likely are you to recommend getting the COVID-19 vaccine to others?"
# label values B8 labelname25
# asdoc tab B8 , append
#
# * B9 data label
# label variable B9 "B9 For those who did not complete the primary dose: Why have you not gotten your recommended number of COVID-19 vaccine?  For those without Boosters: Why have you not gotten your COVID-19 booster?"
# asdoc summarize B9 , append
#
# * B9_A data label
# label variable B9_A "B9_1 Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster? Feel I should have been contacted by now to make an appointment"
# label values B9_A labelname14
# asdoc tab B9_A , append
#
# * B9_B data label
# label variable B9_B "B9_2 Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster? I will not receive it within the recommended efficacy period"
# label values B9_B labelname14
# asdoc tab B9_B , append
#
# * B9_C data label
# label variable B9_C "B9_3 Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster? I am concerned about the news around blood clots"
# label values B9_C labelname14
# asdoc tab B9_C , append
#
# * B9_D data label
# label variable B9_D "B9_4 Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster? I am concerned about information i have seen in the media (tv, newspaper, radio)"
# label values B9_D labelname14
# asdoc tab B9_D , append
#
# * B9_E data label
# label variable B9_E "B9_5 Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster? I am concerned about information i have seen on social media since my first vaccine appointment"
# label values B9_E labelname14
# asdoc tab B9_E , append
#
# * B9_F data label
# label variable B9_F "B9_6 Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster? I am concerned about information i have heard from family and friends since my first vaccine appointment"
# label values B9_F labelname14
# asdoc tab B9_F , append
#
# * B9_G data label
# label variable B9_G "B9_7 Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster?  I am concerned about information i received from a health care professional since my first vaccine appointment"
# label values B9_G labelname14
# asdoc tab B9_G , append
#
# * B9_H data label
# label variable B9_H "B9_8 Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster? I had a bad experience attending my first vaccine appointment"
# label values B9_H labelname14
# asdoc tab B9_H , append
#
# * B9_I data label
# label variable B9_I "B9_9 Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster? I had side effects after the first dose"
# label values B9_I labelname14
# asdoc tab B9_I , append
#
# * B9_J data label
# label variable B9_J "B9_10 Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster? My new appointment is at a different location to last vaccine"
# label values B9_J labelname14
# asdoc tab B9_J , append
#
# * B9_K data label
# label variable B9_K "B9_11 Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster? I’m worried that I won’t get the same vaccine as I had for the first dose"
# label values B9_K labelname14
# asdoc tab B9_K , append
#
# * B9_L data label
# label variable B9_L "B9_12 Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster? I got COVID despite getting the vaccine/ vaccine doesn’t protect me"
# label values B9_L labelname14
# asdoc tab B9_L , append
#
# * B9_M data label
# label variable B9_M "B9_13 Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster? I could not find an appointment near me"
# label values B9_M labelname14
# asdoc tab B9_M , append
#
# * B9_N data label
# label variable B9_N "B9_14 Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster? No vaccines available near me"
# label values B9_N labelname14
# asdoc tab B9_N , append
#
# * B9_O data label
# label variable B9_O "B9_15 Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster? COVID-19 is no longer a concern/ not worried about COVID-19"
# label values B9_O labelname14
# asdoc tab B9_O , append
#
# * B9_P data label
# label variable B9_P "B9_16 Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster? Too busy/ don’t have time"
# label values B9_P labelname14
# asdoc tab B9_P , append
#
# * B9_Q data label
# label variable B9_Q "B9_17 Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster? I don't believe vaccines are effective at protecting me from hospitalization and severe COVID-19"
# label values B9_Q labelname14
# asdoc tab B9_Q , append
#
# * B9_R data label
# label variable B9_R "B9_18 Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster? I don't believe vaccination is important for the health of the community"
# label values B9_R labelname14
# asdoc tab B9_R , append
#
# * B9_S data label
# label variable B9_S "B9_19 Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster? I am worried about the side effects caused by vaccines"
# label values B9_S labelname14
# asdoc tab B9_S , append
#
# * B9_T data label
# label variable B9_T "B9_20 Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster? I do not trust medical experts who encourage vaccination"
# label values B9_T labelname14
# asdoc tab B9_T , append
#
# * B9_U data label
# label variable B9_U "B9_21 Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster? Vaccination is not encouraged by my loved ones"
# label values B9_U labelname14
# asdoc tab B9_U , append
#
# * B9_V data label
# label variable B9_V "B9_22 Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster? Vaccination is not encouraged by religious leaders"
# label values B9_V labelname14
# asdoc tab B9_V , append
#
# * B9_W data label
# label variable B9_W "B9_23 Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster? Vaccination is not encouraged by community leaders"
# label values B9_W labelname14
# asdoc tab B9_W , append
#
# * B9_Y data label
# label variable B9_Y "B9_24 Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster? Completed the 2 COVID-19 boosters"
# label values B9_Y labelname14
# asdoc tab B9_Y , append
#
# * B9_X data label
# label variable B9_X "B9_99 Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster? Other (Specify)"
# label values B9_X labelname14
# asdoc tab B9_X , append
#
# * B9_Z data label
# label variable B9_Z "Add: B9_25 Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster? Two doses are enough, no need for booster shots"
# label values B9_Z labelname14
# asdoc tab B9_Z , append
#
# * B9_AA data label
# label variable B9_AA "Add: B9_26 Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster? With medical condition/got sick during schedule of booster shot"
# label values B9_AA labelname14
# asdoc tab B9_AA , append
#
# * B9_AB data label
# label variable B9_AB "Add: B9_27 Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster? Not required at work/school"
# label values B9_AB labelname14
# asdoc tab B9_AB , append
#
# * B9_AC data label
# label variable B9_AC "Add: B9_28 Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster? Not needed/not necessary"
# label values B9_AC labelname14
# asdoc tab B9_AC , append
#
# * B9_AD data label
# label variable B9_AD "Add: B9_29 Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster? Not informed about booster shot"
# label values B9_AD labelname14
# asdoc tab B9_AD , append
#
# * B9_AE data label
# label variable B9_AE "Add: B9_30 Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster? Pregnant"
# label values B9_AE labelname14
# asdoc tab B9_AE , append
#
# * B9_AF data label
# label variable B9_AF "Add: B9_31 Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster? Do not want to have booster shot"
# label values B9_AF labelname14
# asdoc tab B9_AF , append
#
# * B9_AG data label
# label variable B9_AG "Add: B9_32 Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster? One booster is enough"
# label values B9_AG labelname14
# asdoc tab B9_AG , append
#
# * B9_AH data label
# label variable B9_AH "Add: B9_33 Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster? Was not able to go on scheduled date (went to the province, resigned from work)"
# label values B9_AH labelname14
# asdoc tab B9_AH , append
#
# * B9_AI data label
# label variable B9_AI "Add: B9_34 Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster? Just had booster (recently)"
# label values B9_AI labelname14
# asdoc tab B9_AI , append
#
# * B9_other data label
# label variable B9_other "B9_other Why have you not gotten your recommended number of COVID-19 vaccine? Why have you not gotten your COVID-19 booster? Other"
# asdoc summarize B9_other , append
#
# * B10 data label
# label variable B10 "B10 For those with only 1 dose (Pfizer/Sinovac/Astrazeneca): Do you intend to get the second COVID-19 vaccine?; For those without Boosters: Do you intend to get the booster dose?"
# label values B10 labelname14
# asdoc tab B10 , append
#
# * B11 data label
# label variable B11 "B11 Have you tried to make an appointment for a vaccine?"
# label values B11 labelname26
# asdoc tab B11 , append
#
# * B12 data label
# label variable B12 "B12 Did you experience any difficulties when booking or attending your COVID-19 vaccine appointment(s)?"
# label values B12 labelname14
# asdoc tab B12 , append
#
# * B13 data label
# label variable B13 "B13 What difficulties did you experience?"
# asdoc summarize B13 , append
#
# * B13_A data label
# label variable B13_A "B13_1 What difficulties did you experience? A. I did not feel safe at the vaccine centre"
# label values B13_A labelname14
# asdoc tab B13_A , append
#
# * B13_B data label
# label variable B13_B "B13_2 What difficulties did you experience?  B. I had difficulty getting transport to my appointment"
# label values B13_B labelname14
# asdoc tab B13_B , append
#
# * B13_C data label
# label variable B13_C "B13_3 What difficulties did you experience?  C. I found it difficult or impossible to book an appointment at a location near to my home"
# label values B13_C labelname14
# asdoc tab B13_C , append
#
# * B13_D data label
# label variable B13_D "B13_4 What difficulties did you experience? D. I had difficulties using the online or phone booking system"
# label values B13_D labelname14
# asdoc tab B13_D , append
#
# * B13_E data label
# label variable B13_E "B13_5 What difficulties did you experience? E. I did not feel I had enough information before my appointment"
# label values B13_E labelname14
# asdoc tab B13_E , append
#
# * B13_98 data label
# label variable B13_98 "B13_98 What difficulties did you experience? Other (specify)"
# label values B13_98 labelname14
# asdoc tab B13_98 , append
#
# * B13_other data label
# label variable B13_other "B13_other What difficulties did you experience?  Other"
# asdoc summarize B13_other , append
#
# * B14 data label
# label variable B14 "B14 Do you intend to get the COVID-19 vaccine?"
# label values B14 labelname27
# asdoc tab B14 , append
#
# * B15 data label
# label variable B15 "B15 What would motivate you to get vaccinated?"
# asdoc summarize B15 , append
#
# * B15_A data label
# label variable B15_A "B15_1 What would motivate you to get vaccinated? Protect my health, health of family/friends, co-workers, community"
# label values B15_A labelname14
# asdoc tab B15_A , append
#
# * B15_B data label
# label variable B15_B "B15_2 What would motivate you to get vaccinated? To get back to work/school"
# label values B15_B labelname14
# asdoc tab B15_B , append
#
# * B15_C data label
# label variable B15_C "B15_3 What would motivate you to get vaccinated? To resume social activities"
# label values B15_C labelname14
# asdoc tab B15_C , append
#
# * B15_D data label
# label variable B15_D "B15_4 What would motivate you to get vaccinated? To resume travel"
# label values B15_D labelname14
# asdoc tab B15_D , append
#
# * B15_E data label
# label variable B15_E "B15_5 What would motivate you to get vaccinated? Because others encouraged me to get vaccinated"
# label values B15_E labelname14
# asdoc tab B15_E , append
#
# * B15_F data label
# label variable B15_F "B15_6 What would motivate you to get vaccinated? More reliable information"
# label values B15_F labelname14
# asdoc tab B15_F , append
#
# * B15_G data label
# label variable B15_G "B15_7 What would motivate you to get vaccinated? People I know getting vaccinated"
# label values B15_G labelname14
# asdoc tab B15_G , append
#
# * B15_H data label
# label variable B15_H "B15_8 What would motivate you to get vaccinated? Required by work/school"
# label values B15_H labelname14
# asdoc tab B15_H , append
#
# * B15_I data label
# label variable B15_I "B15_9 What would motivate you to get vaccinated? Incentives to get vaccinated such as transport reimbursement, paid work leave"
# label values B15_I labelname14
# asdoc tab B15_I , append
#
# * B15_J data label
# label variable B15_J "B15_10 What would motivate you to get vaccinated? Vaccination sites close to me/ community vaccination events"
# label values B15_J labelname14
# asdoc tab B15_J , append
#
# * B15_K data label
# label variable B15_K "B15_11 What would motivate you to get vaccinated? Side effects caused by vaccines are mostly mild"
# label values B15_K labelname14
# asdoc tab B15_K , append
#
# * B15_L data label
# label variable B15_L "B15_12 What would motivate you to get vaccinated? Vaccination is encouraged by medical experts"
# label values B15_L labelname14
# asdoc tab B15_L , append
#
# * B15_M data label
# label variable B15_M "B15_13 What would motivate you to get vaccinated? Vaccination is encouraged by my loved ones"
# label values B15_M labelname14
# asdoc tab B15_M , append
#
# * B15_N data label
# label variable B15_N "B15_14 What would motivate you to get vaccinated? Vaccination is encouraged by religious leaders"
# label values B15_N labelname14
# asdoc tab B15_N , append
#
# * B15_O data label
# label variable B15_O "B15_15 What would motivate you to get vaccinated? Vaccination is encouraged by community leaders"
# label values B15_O labelname14
# asdoc tab B15_O , append
#
# * B15_P data label
# label variable B15_P "B15_16 What would motivate you to get vaccinated? The vaccination site is easily accessible to me"
# label values B15_P labelname14
# asdoc tab B15_P , append
#
# * B15_Q data label
# label variable B15_Q "B15_17 What would motivate you to get vaccinated? Vaccines are free and readily available in the vaccination site"
# label values B15_Q labelname14
# asdoc tab B15_Q , append
#
# * B15_R data label
# label variable B15_R "B15_18 What would motivate you to get vaccinated? Getting vaccinated does not take much time"
# label values B15_R labelname14
# asdoc tab B15_R , append
#
# * B15_98 data label
# label variable B15_98 "B15_98 What would motivate you to get vaccinated? Other (specify)"
# label values B15_98 labelname14
# asdoc tab B15_98 , append
#
# * B15_99 data label
# label variable B15_99 "B15_99 What would motivate you to get vaccinated? Don't know/not sure"
# label values B15_99 labelname14
# asdoc tab B15_99 , append
#
# * B15_other data label
# label variable B15_other "B15_other What would motivate you to get vaccinated? Other"
# asdoc summarize B15_other , append
#
# * B16 data label
# label variable B16 "B16 If you are unsure or do not want to receive the COVID-19 vaccine, please tell us why:"
# asdoc summarize B16 , append
#
# * B16_A data label
# label variable B16_A "B16_1 If you are unsure or do not want to receive the COVID-19 vaccine, please tell us why: Vaccine has negative effect on the body"
# label values B16_A labelname14
# asdoc tab B16_A , append
#
# * B16_B data label
# label variable B16_B "B16_2 If you are unsure or do not want to receive the COVID-19 vaccine, please tell us why: Vaccine will get them more sick"
# label values B16_B labelname14
# asdoc tab B16_B , append
#
# * B16_C data label
# label variable B16_C "B16_3 If you are unsure or do not want to receive the COVID-19 vaccine, please tell us why: They’re old to get vaccinated"
# label values B16_C labelname14
# asdoc tab B16_C , append
#
# * B16_D data label
# label variable B16_D "B16_4 If you are unsure or do not want to receive the COVID-19 vaccine, please tell us why: Vaccine will cause severe illness and death"
# label values B16_D labelname14
# asdoc tab B16_D , append
#
# * B16_E data label
# label variable B16_E "B16_5 If you are unsure or do not want to receive the COVID-19 vaccine, please tell us why: Worried about side effects"
# label values B16_E labelname14
# asdoc tab B16_E , append
#
# * B16_F data label
# label variable B16_F "B16_6 If you are unsure or do not want to receive the COVID-19 vaccine, please tell us why: Do not trust the government"
# label values B16_F labelname14
# asdoc tab B16_F , append
#
# * B16_G data label
# label variable B16_G "B16_7 If you are unsure or do not want to receive the COVID-19 vaccine, please tell us why: Do not believe COVID-19 is a real disease"
# label values B16_G labelname14
# asdoc tab B16_G , append
#
# * B16_H data label
# label variable B16_H "B16_8 If you are unsure or do not want to receive the COVID-19 vaccine, please tell us why: Do not believe that COVID-19 vaccines will protect them"
# label values B16_H labelname14
# asdoc tab B16_H , append
#
# * B16_I data label
# label variable B16_I "B16_9 If you are unsure or do not want to receive the COVID-19 vaccine, please tell us why: Do not believe that they will get COVID-19"
# label values B16_I labelname14
# asdoc tab B16_I , append
#
# * B16_J data label
# label variable B16_J "B16_10 If you are unsure or do not want to receive the COVID-19 vaccine, please tell us why: Have a pre-existing medical condition that prevents them from getting vaccinated"
# label values B16_J labelname14
# asdoc tab B16_J , append
#
# * B16_K data label
# label variable B16_K "B16_11 If you are unsure or do not want to receive the COVID-19 vaccine, please tell us why: Too busy/no time/does not work with work or schedule"
# label values B16_K labelname14
# asdoc tab B16_K , append
#
# * B16_L data label
# label variable B16_L "B16_12 If you are unsure or do not want to receive the COVID-19 vaccine, please tell us why: Vaccine not available near me"
# label values B16_L labelname14
# asdoc tab B16_L , append
#
# * B16_M data label
# label variable B16_M "Add: B16_13 If you are unsure or do not want to receive the COVID-19 vaccine, please tell us why: No reason cited"
# label values B16_M labelname14
# asdoc tab B16_M , append
#
# * B16_N data label
# label variable B16_N "Add: B16_14 If you are unsure or do not want to receive the COVID-19 vaccine, please tell us why: Not required"
# label values B16_N labelname14
# asdoc tab B16_N , append
#
# * B16_O data label
# label variable B16_O "Add: B16_15 If you are unsure or do not want to receive the COVID-19 vaccine, please tell us why: No schedule yet"
# label values B16_O labelname14
# asdoc tab B16_O , append
#
# * B16_P data label
# label variable B16_P "Add: B16_16 If you are unsure or do not want to receive the COVID-19 vaccine, please tell us why: Satisfied with primary dose"
# label values B16_P labelname14
# asdoc tab B16_P , append
#
# * B16_98 data label
# label variable B16_98 "B16_98 If you are unsure or do not want to receive the COVID-19 vaccine, please tell us why: Others, specify"
# label values B16_98 labelname14
# asdoc tab B16_98 , append
#
# * B16_other data label
# label variable B16_other "B16_other If you are unsure or do not want to receive the COVID-19 vaccine, please tell us why: Others"
# asdoc summarize B16_other , append
#
# * B17 data label
# label variable B17 "B17 How many children between the age of 5 and 17 do you have in this household for whom you are the parent or primary caregiver?"
# asdoc summarize B17 , append
#
# * B18 data label
# label variable B18 "B18 To your knowledge, has/have any of the child/ren aged 5-17 years in the household had COVID-19?"
# label values B18 labelname19
# asdoc tab B18 , append
#
# * B19 data label
# label variable B19 "B19 What sort of care did the child/ren receive for COVID?"
# label values B19 labelname20
# asdoc tab B19 , append
#
# * B20 data label
# label variable B20 "B20 Has/ have all child/ren 5-17 years in this household received the COVID-19 vaccine?"
# asdoc summarize B20 , append
#
# * B20_A data label
# label variable B20_A "B20_A Has/ have all child/ren 5-17 years in this household received the COVID-19 vaccine? A. For children 12-17 years, yes, completed primary doses plus one booster dose"
# label values B20_A labelname14
# asdoc tab B20_A , append
#
# * B20_B data label
# label variable B20_B "B20_B Has/ have all child/ren 5-17 years in this household received the COVID-19 vaccine? B. For children 12-17 years, completed primary doses only; no booster"
# label values B20_B labelname14
# asdoc tab B20_B , append
#
# * B20_C data label
# label variable B20_C "B20_C Has/ have all child/ren 5-17 years in this household received the COVID-19 vaccine? C. For children 5-11 years, yes, completed primary doses"
# label values B20_C labelname14
# asdoc tab B20_C , append
#
# * B20_D data label
# label variable B20_D "B20_D Has/ have all child/ren 5-17 years in this household received the COVID-19 vaccine? D. Yes, one dose only"
# label values B20_D labelname14
# asdoc tab B20_D , append
#
# * B20_0 data label
# label variable B20_0 "B20_0 Has/ have all child/ren 5-17 years in this household received the COVID-19 vaccine? E. No"
# label values B20_0 labelname14
# asdoc tab B20_0 , append
#
# * B21 data label
# label variable B21 "B21 How easy was it for you to get a COVID-19 vaccine for child/ren?"
# label values B21 labelname22
# asdoc tab B21 , append
#
# * B22 data label
# label variable B22 "B22 At what kind of place did you receive the most recent dose of COVID-19 vaccine for your child/ren? (add category)"
# label values B22 labelname28
# asdoc tab B22 , append
#
# * B22_other data label
# label variable B22_other "B22_other At what kind of place did you receive the most recent dose of COVID-19 vaccine for your child/ren?  Other"
# asdoc summarize B22_other , append
#
# * B23 data label
# label variable B23 "B23 Do you intend to get the recommended number of COVID-19 vaccines for your child/ren?"
# label values B23 labelname29
# asdoc tab B23 , append
#
# * B24 data label
# label variable B24 "B24 What would motivate you to get your child/ren fully vaccinated?"
# asdoc summarize B24 , append
#
# * B24_A data label
# label variable B24_A "B24_1 What would motivate you to get your child/ren fully vaccinated? Protect my child’s health and health of family/friends"
# label values B24_A labelname14
# asdoc tab B24_A , append
#
# * B24_B data label
# label variable B24_B "B24_2 What would motivate you to get your child/ren fully vaccinated? To get back to work/school/daycare/childcare"
# label values B24_B labelname14
# asdoc tab B24_B , append
#
# * B24_C data label
# label variable B24_C "B24_3 What would motivate you to get your child/ren fully vaccinated? To resume social activities"
# label values B24_C labelname14
# asdoc tab B24_C , append
#
# * B24_D data label
# label variable B24_D "B24_4 What would motivate you to get your child/ren fully vaccinated? To resume travel"
# label values B24_D labelname14
# asdoc tab B24_D , append
#
# * B24_E data label
# label variable B24_E "B24_5 What would motivate you to get your child/ren fully vaccinated? Because others encouraged me to get vaccinated"
# label values B24_E labelname14
# asdoc tab B24_E , append
#
# * B24_F data label
# label variable B24_F "B24_6 What would motivate you to get your child/ren fully vaccinated? More reliable information"
# label values B24_F labelname14
# asdoc tab B24_F , append
#
# * B24_G data label
# label variable B24_G "B24_7 What would motivate you to get your child/ren fully vaccinated? People i know getting vaccinated"
# label values B24_G labelname14
# asdoc tab B24_G , append
#
# * B24_H data label
# label variable B24_H "B24_8 What would motivate you to get your child/ren fully vaccinated? Required by work/school"
# label values B24_H labelname14
# asdoc tab B24_H , append
#
# * B24_I data label
# label variable B24_I "B24_9 What would motivate you to get your child/ren fully vaccinated? Incentives to get vaccinated such as transport reimbursement, paid work leave"
# label values B24_I labelname14
# asdoc tab B24_I , append
#
# * B24_J data label
# label variable B24_J "B24_10 What would motivate you to get your child/ren fully vaccinated? Vaccination sites close to me/ community vaccination events"
# label values B24_J labelname14
# asdoc tab B24_J , append
#
# * B24_K data label
# label variable B24_K "Add: B24_11 What would motivate you to get your child/ren fully vaccinated? If  proven to be 100% safe for children"
# label values B24_K labelname14
# asdoc tab B24_K , append
#
# * B24_L data label
# label variable B24_L "Add: B24_12 What would motivate you to get your child/ren fully vaccinated? None, no reason, just don't want my child/children to get vaccinated"
# label values B24_L labelname14
# asdoc tab B24_L , append
#
# * B24_98 data label
# label variable B24_98 "B24_98 What would motivate you to get your child/ren fully vaccinated? Other (specify)"
# label values B24_98 labelname14
# asdoc tab B24_98 , append
#
# * B24_99 data label
# label variable B24_99 ""
# label values B24_99 labelname14
# asdoc tab B24_99 , append
#
# * B24_other data label
# label variable B24_other "B24_other What would motivate you to get your child/ren fully vaccinated? Other"
# asdoc summarize B24_other , append
#
# * B25 data label
# label variable B25 "B25 If you are unsure or do not want to receive the COVID-19 vaccine for your child/ren, please tell us why:"
# asdoc summarize B25 , append
#
# * B25_A data label
# label variable B25_A "B25_1 If you are unsure or do not want to receive the COVID-19 vaccine for your child/ren, please tell us why: Vaccine has negative effect on the body"
# label values B25_A labelname14
# asdoc tab B25_A , append
#
# * B25_B data label
# label variable B25_B "B25_2 If you are unsure or do not want to receive the COVID-19 vaccine for your child/ren, please tell us why: Vaccine will get them more sick"
# label values B25_B labelname14
# asdoc tab B25_B , append
#
# * B25_C data label
# label variable B25_C "B25_3 If you are unsure or do not want to receive the COVID-19 vaccine for your child/ren, please tell us why: They’re old to get vaccinated"
# label values B25_C labelname14
# asdoc tab B25_C , append
#
# * B25_D data label
# label variable B25_D "B25_4 If you are unsure or do not want to receive the COVID-19 vaccine for your child/ren, please tell us why: Vaccine will cause severe illness and death"
# label values B25_D labelname14
# asdoc tab B25_D , append
#
# * B25_E data label
# label variable B25_E "B25_5 If you are unsure or do not want to receive the COVID-19 vaccine for your child/ren, please tell us why: Worried about side effects"
# label values B25_E labelname14
# asdoc tab B25_E , append
#
# * B25_F data label
# label variable B25_F "B25_6 If you are unsure or do not want to receive the COVID-19 vaccine for your child/ren, please tell us why: Do not trust the government"
# label values B25_F labelname14
# asdoc tab B25_F , append
#
# * B25_G data label
# label variable B25_G "B25_7 If you are unsure or do not want to receive the COVID-19 vaccine for your child/ren, please tell us why: Do not believe covid-19 is a real disease"
# label values B25_G labelname14
# asdoc tab B25_G , append
#
# * B25_H data label
# label variable B25_H "B25_8 If you are unsure or do not want to receive the COVID-19 vaccine for your child/ren, please tell us why: Do not believe that covid-19 vaccines will protect them"
# label values B25_H labelname14
# asdoc tab B25_H , append
#
# * B25_I data label
# label variable B25_I "B25_9 If you are unsure or do not want to receive the COVID-19 vaccine for your child/ren, please tell us why: Do not believe that they will get covid-19"
# label values B25_I labelname14
# asdoc tab B25_I , append
#
# * B25_J data label
# label variable B25_J "B25_10 If you are unsure or do not want to receive the COVID-19 vaccine for your child/ren, please tell us why: Have a pre-existing medical condition that prevents them from getting vaccinated"
# label values B25_J labelname14
# asdoc tab B25_J , append
#
# * B25_K data label
# label variable B25_K "B25_11 If you are unsure or do not want to receive the COVID-19 vaccine for your child/ren, please tell us why: Vaccine not available near me"
# label values B25_K labelname14
# asdoc tab B25_K , append
#
# * B25_98 data label
# label variable B25_98 "B25_98 If you are unsure or do not want to receive the COVID-19 vaccine for your child/ren, please tell us why: Others (specify)"
# label values B25_98 labelname14
# asdoc tab B25_98 , append
#
# * B25_other data label
# label variable B25_other "B25_other If you are unsure or do not want to receive the COVID-19 vaccine for your child/ren, please tell us why: Others"
# asdoc summarize B25_other , append
#
# * B26 data label
# label variable B26 "B26 How many household members are over 59 years of age?"
# asdoc summarize B26 , append
#
# * B27_repeat_count data label
# label variable B27_repeat_count "B27_repeat_count What are the ages of the household members over 59 years?"
# asdoc summarize B27_repeat_count , append
#
# * count_hm_1 data label
# label variable count_hm_1 "count_hm_1"
# asdoc summarize count_hm_1 , append
#
# * HM_1 data label
# label variable HM_1 "HM_1 | HM1 ____ ____ years"
# asdoc summarize HM_1 , append
#
# * count_hm_2 data label
# label variable count_hm_2 "count_hm_2"
# asdoc summarize count_hm_2 , append
#
# * HM_2 data label
# label variable HM_2 "HM_2 | HM2 ____ ____ years"
# asdoc summarize HM_2 , append
#
# * count_hm_3 data label
# label variable count_hm_3 "count_hm_3"
# asdoc summarize count_hm_3 , append
#
# * HM_3 data label
# label variable HM_3 "HM_3 | HM3 ____ ____ years"
# asdoc summarize HM_3 , append
#
# * count_hm_4 data label
# label variable count_hm_4 "count_hm_4"
# asdoc summarize count_hm_4 , append
#
# * HM_4 data label
# label variable HM_4 "HM_4 | HM4 ____ ____ years"
# asdoc summarize HM_4 , append
#
# * count_hm_5 data label
# label variable count_hm_5 "count_hm_5"
# asdoc summarize count_hm_5 , append
#
# * HM_5 data label
# label variable HM_5 "HM_5 | HM5 ____ ____ years"
# asdoc summarize HM_5 , append
#
# * B28 data label
# label variable B28 "B28 To your knowledge, has/have any of the household members over 59 years had COVID-19?"
# label values B28 labelname29
# asdoc tab B28 , append
#
# * B29 data label
# label variable B29 "B29 What sort of care did the household members with COVID-19 receive?"
# label values B29 labelname20
# asdoc tab B29 , append
#
# * B30 data label
# label variable B30 "B30 Have all household members over 59 years in this household received the COVID-19 vaccine?"
# label values B30 labelname30
# asdoc tab B30 , append
#
# * B31 data label
# label variable B31 "B31 Do the household members over 59 years intend to get the COVID-19 vaccine?"
# label values B31 labelname29
# asdoc tab B31 , append
#
# * B32 data label
# label variable B32 "B32 Why have the household members over 59 years not gotten vaccinated against COVID-19?"
# asdoc summarize B32 , append
#
# * B32_A data label
# label variable B32_A "B32_1 Why have the household members over 59 years not gotten vaccinated against COVID-19? | Vaccine has negative effect on the body"
# label values B32_A labelname14
# asdoc tab B32_A , append
#
# * B32_B data label
# label variable B32_B "B32_2 Why have the household members over 59 years not gotten vaccinated against COVID-19? | Vaccine will get them more sick"
# label values B32_B labelname14
# asdoc tab B32_B , append
#
# * B32_C data label
# label variable B32_C "B32_3 Why have the household members over 59 years not gotten vaccinated against COVID-19? | They’re old to get vaccinated"
# label values B32_C labelname14
# asdoc tab B32_C , append
#
# * B32_D data label
# label variable B32_D "B32_4 Why have the household members over 59 years not gotten vaccinated against COVID-19? | Vaccine will cause severe illness and death"
# label values B32_D labelname14
# asdoc tab B32_D , append
#
# * B32_E data label
# label variable B32_E "B32_5 Why have the household members over 59 years not gotten vaccinated against COVID-19? | Worried about side effects"
# label values B32_E labelname14
# asdoc tab B32_E , append
#
# * B32_F data label
# label variable B32_F "B32_6 Why have the household members over 59 years not gotten vaccinated against COVID-19? | Do not trust the government"
# label values B32_F labelname14
# asdoc tab B32_F , append
#
# * B32_G data label
# label variable B32_G "B32_7 Why have the household members over 59 years not gotten vaccinated against COVID-19? | Do not believe COVID-19 is a real disease"
# label values B32_G labelname14
# asdoc tab B32_G , append
#
# * B32_H data label
# label variable B32_H "B32_8 Why have the household members over 59 years not gotten vaccinated against COVID-19? | Do not believe that COVID-19 vaccines will protect them"
# label values B32_H labelname14
# asdoc tab B32_H , append
#
# * B32_I data label
# label variable B32_I "B32_9 Why have the household members over 59 years not gotten vaccinated against COVID-19? | Do not believe that they will get COVID-19"
# label values B32_I labelname14
# asdoc tab B32_I , append
#
# * B32_J data label
# label variable B32_J "B32_10 Why have the household members over 59 years not gotten vaccinated against COVID-19? | Have a pre-existing medical condition that prevents them from getting vaccinated"
# label values B32_J labelname14
# asdoc tab B32_J , append
#
# * B32_K data label
# label variable B32_K "B32_11 Why have the household members over 59 years not gotten vaccinated against COVID-19? | Vaccine not available near me"
# label values B32_K labelname14
# asdoc tab B32_K , append
#
# * B32_98 data label
# label variable B32_98 "B32_98 Why have the household members over 59 years not gotten vaccinated against COVID-19? | Others, (specify)"
# label values B32_98 labelname14
# asdoc tab B32_98 , append
#
# * B32_other data label
# label variable B32_other "B32_other Why have the household members over 59 years not gotten vaccinated against COVID-19? | Others"
# asdoc summarize B32_other , append
#
# * B33 data label
# label variable B33 "B33 Do you intend to get the COVID-19 vaccine for your child/ren under five years when vaccine is available?"
# label values B33 labelname29
# asdoc tab B33 , append
#
# * B34 data label
# ...
# asdoc summarize D83 , append
#
# * simserial data label
# label variable simserial "simserial"
# asdoc summarize simserial , append
#
# * today data label
# label variable today "today"
# asdoc summarize today , append
#
# * starttime data label
# label variable starttime "starttime"
# asdoc summarize starttime , append
#
# * endtime data label
# label variable endtime "endtime"
# asdoc summarize endtime , append
#
# * deviceid data label
# label variable deviceid "deviceid"
# asdoc summarize deviceid , append
#
# * subscriberid data label
# label variable subscriberid "subscriberid"
# asdoc summarize subscriberid , append
#
# * simid data label
# label variable simid "simid"
# asdoc summarize simid , append
#
# * devicephonenum data label
# label variable devicephonenum "devicephonenum"
# asdoc summarize devicephonenum , append
#
# * username data label
# label variable username "username"
# asdoc summarize username , append
#
# * device_info data label
# label variable device_info "device_info"
# asdoc summarize device_info , append
#
# * duration data label
# label variable duration "duration"
# asdoc summarize duration , append
#
# * instanceID data label
# label variable instanceID "instanceID"
# asdoc summarize instanceID , append
#
# * formdef_version data label
# label variable formdef_version "formdef_version"
# asdoc summarize formdef_version , append
#
# * KEY data label
# label variable KEY "KEY"
# asdoc summarize KEY , append
#
# * KEY_HH data label
# label variable KEY_HH "KEY-HH"
# asdoc summarize KEY_HH , append
#
# * A1_1 data label
# label variable A1_1 "A1_1 No."
# asdoc summarize A1_1 , append
#
# * A2_1 data label
# label variable A2_1 "A2_1 Name"
# asdoc summarize A2_1 , append
#
# * A3_1 data label
# label variable A3_1 "A3_1 Relation to head of household"
# label values A3_1 labelname48
# asdoc tab A3_1 , append
#
# * A4_1 data label
# label variable A4_1 "A4_1 Age"
# asdoc summarize A4_1 , append
#
# * A5_1 data label
# label variable A5_1 "A5_1 Sex"
# label values A5_1 labelname49
# asdoc tab A5_1 , append
#
# * A6_1 data label
# label variable A6_1 "A6_1 Marital Status"
# label values A6_1 labelname50
# asdoc tab A6_1 , append
#
# * count_household_2 data label
# label variable count_household_2 "count_household_2"
# asdoc summarize count_household_2 , append
#
# * A1_2 data label
# label variable A1_2 "A1_2 No."
# asdoc summarize A1_2 , append
#
# * A2_2 data label
# label variable A2_2 "A2_2 Name"
# asdoc summarize A2_2 , append
#
# * A3_2 data label
# label variable A3_2 "A3_2 Relation to head of household"
# label values A3_2 labelname48
# asdoc tab A3_2 , append
#
# * A4_2 data label
# label variable A4_2 "A4_2 Age"
# asdoc summarize A4_2 , append
#
# * A5_2 data label
# label variable A5_2 "A5_2 Sex"
# label values A5_2 labelname49
# asdoc tab A5_2 , append
#
# * A6_2 data label
# label variable A6_2 "A6_2 Marital Status"
# label values A6_2 labelname50
# asdoc tab A6_2 , append
#
# * count_household_3 data label
# label variable count_household_3 "count_household_3"
# asdoc summarize count_household_3 , append
#
# * A1_3 data label
# label variable A1_3 "A1_3 No."
# asdoc summarize A1_3 , append
#
# * A2_3 data label
# label variable A2_3 "A2_3 Name"
# asdoc summarize A2_3 , append
#
# * A3_3 data label
# label variable A3_3 "A3_3 Relation to head of household"
# label values A3_3 labelname48
# asdoc tab A3_3 , append
#
# * A4_3 data label
# label variable A4_3 "A4_3 Age"
# asdoc summarize A4_3 , append
#
# * A5_3 data label
# label variable A5_3 "A5_3 Sex"
# label values A5_3 labelname49
# asdoc tab A5_3 , append
#
# * A6_3 data label
# label variable A6_3 "A6_3 Marital Status"
# label values A6_3 labelname50
# asdoc tab A6_3 , append
#
# * count_household_4 data label
# label variable count_household_4 "count_household_4"
# asdoc summarize count_household_4 , append
#
# * A1_4 data label
# label variable A1_4 "A1_4 No."
# asdoc summarize A1_4 , append
#
# * A2_4 data label
# label variable A2_4 "A2_4 Name"
# asdoc summarize A2_4 , append
#
# * A3_4 data label
# label variable A3_4 "A3_4 Relation to head of household"
# label values A3_4 labelname48
# asdoc tab A3_4 , append
#
# * A4_4 data label
# label variable A4_4 "A4_4 Age"
# asdoc summarize A4_4 , append
#
# * A5_4 data label
# label variable A5_4 "A5_4 Sex"
# label values A5_4 labelname49
# asdoc tab A5_4 , append
#
# * A6_4 data label
# label variable A6_4 "A6_4 Marital Status"
# label values A6_4 labelname50
# asdoc tab A6_4 , append
#
# * count_household_5 data label
# label variable count_household_5 "count_household_5"
# asdoc summarize count_household_5 , append
#
# * A1_5 data label
# label variable A1_5 "A1_5 No."
# asdoc summarize A1_5 , append
#
# * A2_5 data label
# label variable A2_5 "A2_5 Name"
# asdoc summarize A2_5 , append
#
# * A3_5 data label
# label variable A3_5 "A3_5 Relation to head of household"
# label values A3_5 labelname48
# asdoc tab A3_5 , append
#
# * A4_5 data label
# label variable A4_5 "A4_5 Age"
# asdoc summarize A4_5 , append
#
# * A5_5 data label
# label variable A5_5 "A5_5 Sex"
# label values A5_5 labelname49
# asdoc tab A5_5 , append
#
# * A6_5 data label
# label variable A6_5 "A6_5 Marital Status"
# label values A6_5 labelname50
# asdoc tab A6_5 , append
#
# * count_household_6 data label
# label variable count_household_6 "count_household_6"
# asdoc summarize count_household_6 , append
#
# * A1_6 data label
# label variable A1_6 "A1_6 No."
# asdoc summarize A1_6 , append
#
# * A2_6 data label
# label variable A2_6 "A2_6 Name"
# asdoc summarize A2_6 , append
#
# * A3_6 data label
# label variable A3_6 "A3_6 Relation to head of household"
# label values A3_6 labelname48
# asdoc tab A3_6 , append
#
# * A4_6 data label
# label variable A4_6 "A4_6 Age"
# asdoc summarize A4_6 , append
#
# * A5_6 data label
# label variable A5_6 "A5_6 Sex"
# label values A5_6 labelname49
# asdoc tab A5_6 , append
#
# * A6_6 data label
# label variable A6_6 "A6_6 Marital Status"
# label values A6_6 labelname50
# asdoc tab A6_6 , append
#
# * count_household_7 data label
# label variable count_household_7 "count_household_7"
# asdoc summarize count_household_7 , append
#
# * A1_7 data label
# label variable A1_7 "A1_7 No."
# asdoc summarize A1_7 , append
#
# * A2_7 data label
# label variable A2_7 "A2_7 Name"
# asdoc summarize A2_7 , append
#
# * A3_7 data label
# label variable A3_7 "A3_7 Relation to head of household"
# label values A3_7 labelname48
# asdoc tab A3_7 , append
#
# * A4_7 data label
# label variable A4_7 "A4_7 Age"
# asdoc summarize A4_7 , append
#
# * A5_7 data label
# label variable A5_7 "A5_7 Sex"
# label values A5_7 labelname49
# asdoc tab A5_7 , append
#
# * A6_7 data label
# label variable A6_7 "A6_7 Marital Status"
# label values A6_7 labelname50
# asdoc tab A6_7 , append
#
# * count_household_8 data label
# label variable count_household_8 "count_household_8"
# asdoc summarize count_household_8 , append
#
# * A1_8 data label
# label variable A1_8 "A1_8 No."
# asdoc summarize A1_8 , append
#
# * A2_8 data label
# label variable A2_8 "A2_8 Name"
# asdoc summarize A2_8 , append
#
# * A3_8 data label
# label variable A3_8 "A3_8 Relation to head of household"
# label values A3_8 labelname48
# asdoc tab A3_8 , append
#
# * A4_8 data label
# label variable A4_8 "A4_8 Age"
# asdoc summarize A4_8 , append
#
# * A5_8 data label
# label variable A5_8 "A5_8 Sex"
# label values A5_8 labelname49
# asdoc tab A5_8 , append
#
# * A6_8 data label
# label variable A6_8 "A6_8 Marital Status"
# label values A6_8 labelname50
# asdoc tab A6_8 , append
#
# * count_household_9 data label
# label variable count_household_9 "count_household_9"
# asdoc summarize count_household_9 , append
#
# * A1_9 data label
# label variable A1_9 "A1_9 No."
# asdoc summarize A1_9 , append
#
# * A2_9 data label
# label variable A2_9 "A2_9 Name"
# asdoc summarize A2_9 , append
#
# * A3_9 data label
# label variable A3_9 "A3_9 Relation to head of household"
# label values A3_9 labelname48
# asdoc tab A3_9 , append
#
# * A4_9 data label
# label variable A4_9 "A4_9 Age"
# asdoc summarize A4_9 , append
#
# * A5_9 data label
# label variable A5_9 "A5_9 Sex"
# label values A5_9 labelname49
# asdoc tab A5_9 , append
#
# * A6_9 data label
# label variable A6_9 "A6_9 Marital Status"
# label values A6_9 labelname50
# asdoc tab A6_9 , append
#
# * count_household_10 data label
# label variable count_household_10 "count_household_10"
# asdoc summarize count_household_10 , append
#
# * A1_10 data label
# label variable A1_10 "A1_10 No."
# asdoc summarize A1_10 , append
#
# * A2_10 data label
# label variable A2_10 "A2_10 Name"
# asdoc summarize A2_10 , append
#
# * A3_10 data label
# label variable A3_10 "A3_10 Relation to head of household"
# label values A3_10 labelname48
# asdoc tab A3_10 , append
#
# * A4_10 data label
# label variable A4_10 "A4_10 Age"
# asdoc summarize A4_10 , append
#
# * A5_10 data label
# label variable A5_10 "A5_10 Sex"
# label values A5_10 labelname49
# asdoc tab A5_10 , append
#
# * A6_10 data label
# label variable A6_10 "A6_10 Marital Status"
# label values A6_10 labelname50
# asdoc tab A6_10 , append
#
# * count_household_11 data label
# label variable count_household_11 "count_household_11"
# asdoc summarize count_household_11 , append
#
# * A1_11 data label
# label variable A1_11 "A1_11 No."
# asdoc summarize A1_11 , append
#
# * A2_11 data label
# label variable A2_11 "A2_11 Name"
# asdoc summarize A2_11 , append
#
# * A3_11 data label
# label variable A3_11 "A3_11 Relation to head of household"
# label values A3_11 labelname48
# asdoc tab A3_11 , append
#
# * A4_11 data label
# label variable A4_11 "A4_11 Age"
# asdoc summarize A4_11 , append
#
# * A5_11 data label
# label variable A5_11 "A5_11 Sex"
# label values A5_11 labelname49
# asdoc tab A5_11 , append
#
# * A6_11 data label
# label variable A6_11 "A6_11 Marital Status"
# label values A6_11 labelname50
# asdoc tab A6_11 , append
#
# * count_household_12 data label
# label variable count_household_12 "count_household_12"
# asdoc summarize count_household_12 , append
#
# * A1_12 data label
# label variable A1_12 "A1_12 No."
# asdoc summarize A1_12 , append
#
# * A2_12 data label
# label variable A2_12 "A2_12 Name"
# asdoc summarize A2_12 , append
#
# * A3_12 data label
# label variable A3_12 "A3_12 Relation to head of household"
# label values A3_12 labelname48
# asdoc tab A3_12 , append
#
# * A4_12 data label
# label variable A4_12 "A4_12 Age"
# asdoc summarize A4_12 , append
#
# * A5_12 data label
# label variable A5_12 "A5_12 Sex"
# label values A5_12 labelname49
# asdoc tab A5_12 , append
#
# * A6_12 data label
# label variable A6_12 "A6_12 Marital Status"
# label values A6_12 labelname50
# asdoc tab A6_12 , append
#
# * count_household_13 data label
# label variable count_household_13 "count_household_13"
# asdoc summarize count_household_13 , append
#
# * A1_13 data label
# label variable A1_13 "A1_13 No."
# asdoc summarize A1_13 , append
#
# * A2_13 data label
# label variable A2_13 "A2_13 Name"
# asdoc summarize A2_13 , append
#
# * A3_13 data label
# label variable A3_13 "A3_13 Relation to head of household"
# label values A3_13 labelname48
# asdoc tab A3_13 , append
#
# * A4_13 data label
# label variable A4_13 "A4_13 Age"
# asdoc summarize A4_13 , append
#
# * A5_13 data label
# label variable A5_13 "A5_13 Sex"
# label values A5_13 labelname49
# asdoc tab A5_13 , append
#
# * A6_13 data label
# label variable A6_13 "A6_13 Marital Status"
# label values A6_13 labelname50
# asdoc tab A6_13 , append
#
# * count_household_14 data label
# label variable count_household_14 "count_household_14"
# asdoc summarize count_household_14 , append
#
# * A1_14 data label
# label variable A1_14 "A1_14 No."
# asdoc summarize A1_14 , append
#
# * A2_14 data label
# label variable A2_14 "A2_14 Name"
# asdoc summarize A2_14 , append
#
# * A3_14 data label
# label variable A3_14 "A3_14 Relation to head of household"
# label values A3_14 labelname48
# asdoc tab A3_14 , append
#
# * A4_14 data label
# label variable A4_14 "A4_14 Age"
# asdoc summarize A4_14 , append
#
# * A5_14 data label
# label variable A5_14 "A5_14 Sex"
# label values A5_14 labelname49
# asdoc tab A5_14 , append
#
# * A6_14 data label
# label variable A6_14 "A6_14 Marital Status"
# label values A6_14 labelname50
# asdoc tab A6_14 , append
#
# * count_household_15 data label
# label variable count_household_15 "count_household_15"
# asdoc summarize count_household_15 , append
#
# * A1_15 data label
# label variable A1_15 "A1_15 No."
# asdoc summarize A1_15 , append
#
# * A2_15 data label
# label variable A2_15 "A2_15 Name"
# asdoc summarize A2_15 , append
#
# * A3_15 data label
# label variable A3_15 "A3_15 Relation to head of household"
# label values A3_15 labelname48
# asdoc tab A3_15 , append
#
# * A4_15 data label
# label variable A4_15 "A4_15 Age"
# asdoc summarize A4_15 , append
#
# * A5_15 data label
# label variable A5_15 "A5_15 Sex"
# label values A5_15 labelname49
# asdoc tab A5_15 , append
#
# * A6_15 data label
# label variable A6_15 "A6_15 Marital Status"
# label values A6_15 labelname50
# asdoc tab A6_15 , append
#
# * count_household_16 data label
# label variable count_household_16 "count_household_16"
# asdoc summarize count_household_16 , append
#
# * A1_16 data label
# label variable A1_16 "A1_16 No."
# asdoc summarize A1_16 , append
#
# * A2_16 data label
# label variable A2_16 "A2_16 Name"
# asdoc summarize A2_16 , append
#
# * A3_16 data label
# label variable A3_16 "A3_16 Relation to head of household"
# label values A3_16 labelname48
# asdoc tab A3_16 , append
#
# * A4_16 data label
# label variable A4_16 "A4_16 Age"
# asdoc summarize A4_16 , append
#
# * A5_16 data label
# label variable A5_16 "A5_16 Sex"
# label values A5_16 labelname49
# asdoc tab A5_16 , append
#
# * A6_16 data label
# label variable A6_16 "A6_16 Marital Status"
# label values A6_16 labelname50
# asdoc tab A6_16 , append
#
# * count_household_17 data label
# label variable count_household_17 "count_household_17"
# asdoc summarize count_household_17 , append
#
# * A1_17 data label
# label variable A1_17 "A1_17 No."
# asdoc summarize A1_17 , append
#
# * A2_17 data label
# label variable A2_17 "A2_17 Name"
# asdoc summarize A2_17 , append
#
# * A3_17 data label
# label variable A3_17 "A3_17 Relation to head of household"
# label values A3_17 labelname48
# asdoc tab A3_17 , append
#
# * A4_17 data label
# label variable A4_17 "A4_17 Age"
# asdoc summarize A4_17 , append
#
# * A5_17 data label
# label variable A5_17 "A5_17 Sex"
# label values A5_17 labelname49
# asdoc tab A5_17 , append
#
# * A6_17 data label
# label variable A6_17 "A6_17 Marital Status"
# label values A6_17 labelname50
# asdoc tab A6_17 , append
#
# * count_household_18 data label
# label variable count_household_18 "count_household_18"
# asdoc summarize count_household_18 , append
#
# * A1_18 data label
# label variable A1_18 "A1_18 No."
# asdoc summarize A1_18 , append
#
# * A2_18 data label
# label variable A2_18 "A2_18 Name"
# asdoc summarize A2_18 , append
#
# * A3_18 data label
# label variable A3_18 "A3_18 Relation to head of household"
# label values A3_18 labelname48
# asdoc tab A3_18 , append
#
# * A4_18 data label
# label variable A4_18 "A4_18 Age"
# asdoc summarize A4_18 , append
#
# * A5_18 data label
# label variable A5_18 "A5_18 Sex"
# label values A5_18 labelname49
# asdoc tab A5_18 , append
#
# * A6_18 data label
# label variable A6_18 "A6_18 Marital Status"
# label values A6_18 labelname50
# asdoc tab A6_18 , append
#
# * num_household data label
# label variable num_household "num_household"
# asdoc summarize num_household , append
#
# * today_hh data label
# label variable today_hh "today"
# asdoc summarize today_hh , append
#
# * starttime_hh data label
# label variable starttime_hh "starttime"
# asdoc summarize starttime_hh , append
#
# * endtime_hh data label
# label variable endtime_hh "endtime"
# asdoc summarize endtime_hh , append
#
# * deviceid_hh data label
# label variable deviceid_hh "deviceid"
# asdoc summarize deviceid_hh , append
#
# * subscriberid_hh data label
# label variable subscriberid_hh "subscriberid"
# asdoc summarize subscriberid_hh , append
#
# * simid_hh data label
# label variable simid_hh "simid"
# asdoc summarize simid_hh , append
#
# * devicephonenum_hh data label
# label variable devicephonenum_hh "devicephonenum"
# asdoc summarize devicephonenum_hh , append
#
# * username_hh data label
# label variable username_hh "username"
# asdoc summarize username_hh , append
#
# * device_info_hh data label
# label variable device_info_hh "device_info"
# asdoc summarize device_info_hh , append
#
# * duration_hh data label
# label variable duration_hh "duration"
# asdoc summarize duration_hh , append
#
# * instanceID_hh data label
# label variable instanceID_hh "instanceID"
# asdoc summarize instanceID_hh , append
#
# * formdef_version_hh data label
# label variable formdef_version_hh "formdef_version"
# asdoc summarize formdef_version_hh , append
